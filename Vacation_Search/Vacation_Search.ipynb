# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_Database.csv")
city_data_df.head(10)
# Out:
#    City_ID           City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0     Georgetown      MY   5.4112  100.3354     79.90        88
# 1        1        Ronchin      FR  50.6000    3.1000     61.21        65
# 2        2  San Cristobal      VE   7.7669  -72.2250     78.46        57
# 3        3    Port Alfred      ZA -33.5906   26.8910     58.15        55
# 4        4    New Norfolk      AU -42.7826  147.0587     53.92        86
# 5        5  Mar Del Plata      AR -38.0023  -57.5575     57.74        78
# 6        6    Yellowknife      CA  62.4560 -114.3525     48.74        52
# 7        7     Vila Velha      BR -20.3297  -40.2925     73.54        80
# 8        8        Rikitea      PF -23.1203 -134.9692     71.94        74
# 9        9         Barrow      US  71.2906 -156.7887     31.01        88
#
#    Cloudiness  Wind Speed Current Description
# 0          96        4.70     overcast clouds
# 1          99        5.03     overcast clouds
# 2          11        5.50          few clouds
# 3          83        3.40       broken clouds
# 4          71        1.01       broken clouds
# 5           0       10.45           clear sky
# 6          49       11.81    scattered clouds
# 7           9        7.07           clear sky
# 8          60       11.05       broken clouds
# 9         100       10.60     overcast clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
max_temp = float(input("What is the maximum temperature in F for your vacation place?: "))
min_temp = float(input("What is the minimum temperature in F for you vacation place?: " ))
# Out:
# What is the maximum temperature in F for your vacation place?: 90
# What is the minimum temperature in F for you vacation place?: 75

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
city_data_temps_df = city_data_df.loc[(city_data_df['Max Temp']>=min_temp) & (city_data_df['Max Temp']<=max_temp)]
city_data_temps_df.tail(50)
# Out:
#      City_ID                     City Country      Lat       Lng  Max Temp  \
# 565      565                    Alofi      NU -19.0595 -169.9187     78.19
# 567      567                 Beruwala      LK   6.4788   79.9828     79.00
# 570      570                      Bud      US  39.4470  -86.1758     87.12
# 578      578              Black River      JM  18.0264  -77.8487     85.30
# 581      581       Sao Felix Do Xingu      BR  -6.6447  -51.9950     86.41
# 583      583                  Sanchor      IN  24.7553   71.7722     83.43
# 585      585              Panama City      PA   8.9936  -79.5197     79.18
# 588      588                 Calabozo      VE   8.9242  -67.4293     82.62
# 589      589                 Cururupu      BR  -1.8283  -44.8683     76.08
# 590      590                    Amapa      BR   1.0000  -52.0000     76.84
# 595      595                     Doha      QA  25.2867   51.5333     89.53
# 597      597                     Lamu      KE  -2.2717   40.9020     76.01
# 598      598                  Kadipur      IN  26.1667   82.3833     75.27
# 603      603                  Awjilah      LY  29.1081   21.2869     81.18
# 605      605            San Policarpo      PH  12.1791  125.5072     77.97
# 606      606            Makakilo City      US  21.3469 -158.0858     82.69
# 611      611                 Sangueya      GN  10.7000  -14.3667     75.67
# 612      612                    Gaoua      BF  10.2992   -3.2508     76.66
# 614      614                 Nanakuli      US  21.3906 -158.1547     84.11
# 621      621                Englehart      CA  47.8169  -79.8664     75.45
# 625      625                  Pizarro      CO   4.9533  -77.3660     81.19
# 631      631                   Ixtapa      MX  20.7000 -105.2000     80.22
# 632      632                  Samarai      PG -10.6167  150.6667     77.83
# 635      635                Les Cayes      HT  18.2000  -73.7500     84.20
# 636      636                   Garowe      SO   8.4054   48.4845     77.11
# 637      637              Morgan City      US  29.6994  -91.2068     86.00
# 640      640                  Mayumba      GA  -3.4320   10.6554     75.13
# 648      648               Kolondieba      ML  11.0882   -6.8926     75.09
# 652      652                 Qui Nhon      VN  13.7667  109.2333     76.32
# 654      654                 Barranco      PA   9.5167  -82.7000     84.74
# 656      656                  Sakakah      SA  29.9697   40.2064     83.39
# 662      662                   Kokopo      PG  -4.3520  152.2633     81.57
# 663      663  Sitio Novo Do Tocantins      BR  -5.5183  -47.4611     88.79
# 664      664                     Esna      EG  25.2934   32.5540     80.98
# 665      665                      Sur      OM  22.5667   59.5289     83.91
# 668      668                  Sompeta      IN  18.9333   84.6000     80.91
# 669      669              La Macarena      CO   2.1837  -73.7849     79.23
# 673      673                  Bontang      ID   0.1333  117.5000     76.26
# 678      678                    Matay      EG  28.4190   30.7792     78.51
# 685      685                 Dong Hoi      VN  17.4833  106.6000     77.63
# 687      687                    Locri      IT  38.2414   16.2623     82.99
# 691      691                Hermiston      US  45.8404 -119.2895     83.10
# 692      692                      Gat      IL  31.6100   34.7642     75.81
# 694      694                   Mizdah      LY  31.4451   12.9801     75.83
# 695      695                     Toma      BF  12.7667   -2.8833     79.59
# 696      696                 Chenzhou      CN  25.8000  113.0333     75.70
# 697      697                  Mafinga      TZ  -7.2500   35.0667     75.15
# 698      698              Kattivakkam      IN  13.2167   80.3167     82.49
# 700      700                Kongoussi      BF  13.3258   -1.5347     83.73
# 702      702                   Waddan      LY  29.1614   16.1390     79.34
#
#      Humidity  Cloudiness  Wind Speed Current Description
# 565        81          13       18.23          light rain
# 567        87         100        7.36          light rain
# 570        61          14        3.69          few clouds
# 578        72          99        8.61          light rain
# 581        35          86        3.40     overcast clouds
# 583        80          96        9.98     overcast clouds
# 585        83          99        8.57     overcast clouds
# 588        69          83        2.75       broken clouds
# 589        89          14        3.18          few clouds
# 590        78          79        3.31       broken clouds
# 595        46          14        2.53          few clouds
# 597        79          54       12.64       broken clouds
# 598        97         100        6.38     overcast clouds
# 603        28           0        8.48           clear sky
# 605        87          33        2.55    scattered clouds
# 606        67          99       20.18     overcast clouds
# 611        95          24        4.03          few clouds
# 612        79          89        3.56     overcast clouds
# 614        70          99       18.30     overcast clouds
# 621        54           2       16.78           clear sky
# 625        79          51        6.82       broken clouds
# 631        96         100        4.52     overcast clouds
# 632        83          99       19.75     overcast clouds
# 635        72          96        9.13     overcast clouds
# 636        71          85       19.04     overcast clouds
# 637        75          50       10.54    scattered clouds
# 640        89         100        9.01          light rain
# 648        88          77        0.98       broken clouds
# 652        90          86        3.85     overcast clouds
# 654        70          82        4.07       broken clouds
# 656        28           0       15.01           clear sky
# 662        72          93       11.34     overcast clouds
# 663        35          79        5.46       broken clouds
# 664        34           3       11.01           clear sky
# 665        70           7       11.07           clear sky
# 668        80         100        4.52     overcast clouds
# 669        76          71        2.10       broken clouds
# 673        91         100        5.08     overcast clouds
# 678        48           0       17.16           clear sky
# 685        82          39        4.36    scattered clouds
# 687        43          69        5.79       broken clouds
# 691        12         100       10.87     overcast clouds
# 692        68           0        4.23           clear sky
# 694        28           0        7.43           clear sky
# 695        71          39        5.82    scattered clouds
# 696        83          28        3.53    scattered clouds
# 697        47           1        4.74           clear sky
# 698        77          97        5.95     overcast clouds
# 700        58          79        6.46       broken clouds
# 702        31           0       10.31           clear sky

# %%
# 4a. Determine if there are any empty rows.
city_data_temps_df.count()
# Out:
# City_ID                247
# City                   247
# Country                247
# Lat                    247
# Lng                    247
# Max Temp               247
# Humidity               247
# Cloudiness             247
# Wind Speed             247
# Current Description    247
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = city_data_temps_df.dropna()
clean_df.count()
# Out:
# City_ID                247
# City                   247
# Country                247
# Lat                    247
# Lng                    247
# Max Temp               247
# Humidity               247
# Cloudiness             247
# Wind Speed             247
# Current Description    247
# dtype: int64

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head()
# Out:
#              City Country  Max Temp Current Description      Lat       Lng  \
# 0      Georgetown      MY     79.90     overcast clouds   5.4112  100.3354
# 2   San Cristobal      VE     78.46          few clouds   7.7669  -72.2250
# 13        Fortuna      US     79.41       broken clouds  40.5982 -124.1573
# 15      Ewa Beach      US     84.09     overcast clouds  21.3156 -158.0072
# 18       Kirakira      SB     82.56     overcast clouds -10.4544  161.9205
#
#    Hotel Name
# 0
# 2
# 13
# 15
# 18

# %%
import numpy as np # for putting Nan value to hotels not found
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    params["location"] = f"{lat},{lng}"
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    print(f"Processing: {row['City']}")
    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url,params=params).json()
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index,"Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        hotel_df.loc[index,"Hotel Name"] = np.NaN
        print("Hotel not found ... Skipping.")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing: Georgetown
# Processing: San Cristobal
# Processing: Fortuna
# Processing: Ewa Beach
# Processing: Kirakira
# Processing: Jamestown
# Processing: Cayenne
# Processing: Progreso
# Processing: Avarua
# Processing: Bubaque
# Processing: Kapaa
# Processing: Hilo
# Processing: Keti Bandar
# Processing: Shelburne
# Processing: Kavaratti
# Processing: Sibolga
# Processing: Albany
# Hotel not found ... Skipping.
# Processing: Half Moon Bay
# Processing: Vaini
# Processing: Atuona
# Processing: Puri
# Processing: Namatanai
# Processing: Wanning
# Processing: Roma
# Processing: Cartagena
# Processing: Hamilton
# Processing: Eureka
# Processing: Valverde Del Camino
# Processing: Fare
# Processing: Lompoc
# Processing: Marzuq
# Hotel not found ... Skipping.
# Processing: Lorengau
# Processing: Qrendi
# Processing: Roanoke Rapids
# Processing: Hun
# Processing: Butaritari
# Processing: Port Blair
# Processing: Pacific Grove
# Processing: Santiago Del Estero
# Processing: Sinnamary
# Processing: Matara
# Processing: Faanui
# Processing: Harper
# Processing: Portland
# Processing: Hithadhoo
# Processing: Salalah
# Processing: San Ramon
# Processing: Fomboni
# Processing: Kahului
# Processing: Najran
# Processing: Naze
# Processing: Hirara
# Processing: Praia
# Processing: Micheweni
# Hotel not found ... Skipping.
# Processing: Buchanan
# Processing: Fallon
# Processing: Vanimo
# Processing: Adrar
# Hotel not found ... Skipping.
# Processing: Victoria
# Processing: Talisay
# Processing: Villa Union
# Processing: Abu Kamal
# Processing: Dothan
# Processing: Akyab
# Processing: Buraydah
# Processing: Bathsheba
# Processing: Sao Filipe
# Processing: Hasaki
# Processing: Grand-Santi
# Processing: Safipur
# Processing: Kati
# Processing: Basco
# Processing: Turayf
# Processing: Pochutla
# Processing: Tarakan
# Processing: Honiara
# Processing: Luba
# Hotel not found ... Skipping.
# Processing: Ponta Do Sol
# Processing: Ibra
# Processing: Saint-Georges
# Processing: Segou
# Processing: Axim
# Processing: Riyadh
# Processing: Broome
# Processing: Cotonou
# Processing: San Juan
# Processing: Bartica
# Processing: Padang
# Processing: Orocue
# Processing: Pemangkat
# Processing: Muli
# Processing: Itarema
# Processing: Karwar
# Processing: Tautira
# Processing: Carutapera
# Processing: Katsuura
# Processing: Coreau
# Processing: Kihei
# Hotel not found ... Skipping.
# Processing: Troy
# Processing: Dubuque
# Processing: Marsh Harbour
# Processing: Niquero
# Processing: Port Moresby
# Processing: Neiafu
# Processing: Goias
# Hotel not found ... Skipping.
# Processing: Susanville
# Processing: Mabaruma
# Processing: Caucel
# Processing: Tenenkou
# Hotel not found ... Skipping.
# Processing: Nalut
# Hotel not found ... Skipping.
# Processing: Gamba
# Hotel not found ... Skipping.
# Processing: Det Udom
# Processing: Palomares
# Processing: Male
# Processing: Kazerun
# Processing: Muscat
# Processing: Hambantota
# Processing: Wana
# Processing: Chakwal
# Processing: Chanute
# Processing: Windsor
# Processing: Tomatlan
# Processing: Natal
# Processing: Iquitos
# Processing: Umm Lajj
# Processing: Jabinyanah
# Processing: The Valley
# Processing: Aquiraz
# Processing: Bandarbeyla
# Processing: San Pedro
# Processing: Havelock
# Processing: Ormara
# Processing: Acapulco
# Processing: Labrea
# Processing: Gewane
# Processing: Avera
# Hotel not found ... Skipping.
# Processing: Jalu
# Processing: Banda Aceh
# Processing: Kalabo
# Processing: Dalbandin
# Processing: Mecca
# Processing: Camacupa
# Hotel not found ... Skipping.
# Processing: Kieta
# Processing: Ventanas
# Processing: Manuk Mangkaw
# Hotel not found ... Skipping.
# Processing: Kalmunai
# Processing: Union Hidalgo
# Processing: Kavieng
# Processing: Hit
# Processing: Ravar
# Processing: Merauke
# Hotel not found ... Skipping.
# Processing: Dire
# Hotel not found ... Skipping.
# Processing: Sabang
# Processing: Tambun
# Processing: Magaria
# Processing: Tamale
# Processing: Cockburn Town
# Processing: Ajdabiya
# Processing: Westport
# Processing: Touros
# Processing: Atar
# Processing: Pitimbu
# Processing: Manado
# Processing: Acarau
# Processing: Meulaboh
# Processing: Oussouye
# Processing: Lazaro Cardenas
# Processing: Siva
# Processing: Ati
# Hotel not found ... Skipping.
# Processing: Swabi
# Processing: Hilton Head Island
# Processing: Lufilufi
# Processing: Quibdo
# Processing: Lakhimpur
# Processing: Berbera
# Processing: Nha Trang
# Processing: Yendi
# Processing: Tateyama
# Processing: Bellavista
# Processing: Ciudad Bolivar
# Processing: Aripuana
# Hotel not found ... Skipping.
# Processing: Mouzouras
# Processing: Iberia
# Processing: Tajao
# Processing: Auki
# Processing: Wilmington
# Processing: Point Fortin
# Processing: Sabla
# Hotel not found ... Skipping.
# Processing: Bambanglipuro
# Processing: Surat
# Processing: Quanzhou
# Processing: Kutum
# Processing: Elat
# Processing: Mundo Nuevo
# Hotel not found ... Skipping.
# Processing: Narasannapeta
# Processing: Carlagan
# Processing: Goderich
# Processing: Alofi
# Processing: Beruwala
# Processing: Bud
# Processing: Black River
# Processing: Sao Felix Do Xingu
# Processing: Sanchor
# Processing: Panama City
# Processing: Calabozo
# Processing: Cururupu
# Processing: Amapa
# Hotel not found ... Skipping.
# Processing: Doha
# Processing: Lamu
# Processing: Kadipur
# Processing: Awjilah
# Hotel not found ... Skipping.
# Processing: San Policarpo
# Processing: Makakilo City
# Processing: Sangueya
# Hotel not found ... Skipping.
# Processing: Gaoua
# Hotel not found ... Skipping.
# Processing: Nanakuli
# Processing: Englehart
# Processing: Pizarro
# Processing: Ixtapa
# Processing: Samarai
# Processing: Les Cayes
# Processing: Garowe
# Processing: Morgan City
# Processing: Mayumba
# Processing: Kolondieba
# Processing: Qui Nhon
# Processing: Barranco
# Processing: Sakakah
# Processing: Kokopo
# Processing: Sitio Novo Do Tocantins
# Processing: Esna
# Processing: Sur
# Processing: Sompeta
# Processing: La Macarena
# Processing: Bontang
# Processing: Matay
# Processing: Dong Hoi
# Processing: Locri
# Processing: Hermiston
# Processing: Gat
# Processing: Mizdah
# Processing: Toma
# Processing: Chenzhou
# Processing: Mafinga
# Hotel not found ... Skipping.
# Processing: Kattivakkam
# Processing: Kongoussi
# Processing: Waddan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna()
clean_hotel_df.head(10)
# Out:
#              City Country  Max Temp Current Description      Lat       Lng  \
# 0      Georgetown      MY     79.90     overcast clouds   5.4112  100.3354
# 2   San Cristobal      VE     78.46          few clouds   7.7669  -72.2250
# 13        Fortuna      US     79.41       broken clouds  40.5982 -124.1573
# 15      Ewa Beach      US     84.09     overcast clouds  21.3156 -158.0072
# 18       Kirakira      SB     82.56     overcast clouds -10.4544  161.9205
# 21      Jamestown      US     79.84    scattered clouds  42.0970  -79.2353
# 25        Cayenne      GF     83.08          light rain   4.9333  -52.3333
# 32       Progreso      MX     88.11     overcast clouds  21.2833  -89.6667
# 36         Avarua      CK     75.06    scattered clouds -21.2078 -159.7750
# 40        Bubaque      GW     81.30    scattered clouds  11.2833  -15.8333
#
#                         Hotel Name
# 0                   Cititel Penang
# 2             Posada Villaven C.A.
# 13      Super 8 by Wyndham Fortuna
# 15             Uncle Junior Robert
# 18                    SanBiz Lodge
# 21  Hampton Inn & Suites Jamestown
# 25                 Hôtel Le Dronmi
# 32               Playa Linda Hotel
# 36                    Paradise Inn
# 40              Casa Dora, Bubaque

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country Code</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} F</dd>
</dl>
"""
# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 

fig = gmaps.figure()
# 11b. Display the figure
# Assign the marker layer to a variable
markers = gmaps.marker_layer(locations,info_box_content = hotel_info)
# Add the layer to the map
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
