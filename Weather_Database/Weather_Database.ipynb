# %% [markdown]
# ## Deliverable 1.  Retrieve the current weather description for each city and create a dataFrame containing the updated weather data.

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
from config import weather_api_key

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)  # to join lattitudes and longitudes as a tuple that have the same index
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_url = url + "&q=" + city.replace(" ","+")

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in our list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | ronchin
# Processing Record 3 of Set 1 | san cristobal
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 6 of Set 1 | mar del plata
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | vila velha
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | barrow
# Processing Record 11 of Set 1 | constitucion
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | mount isa
# Processing Record 14 of Set 1 | santa vitoria do palmar
# Processing Record 15 of Set 1 | fortuna
# Processing Record 16 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 17 of Set 1 | san patricio
# Processing Record 18 of Set 1 | ewa beach
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | port elizabeth
# Processing Record 21 of Set 1 | kirakira
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | luderitz
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | port-cartier
# Processing Record 26 of Set 1 | nauen
# Processing Record 27 of Set 1 | lebu
# Processing Record 28 of Set 1 | cayenne
# Processing Record 29 of Set 1 | castro
# Processing Record 30 of Set 1 | puerto ayora
# Processing Record 31 of Set 1 | kruisfontein
# Processing Record 32 of Set 1 | ilulissat
# Processing Record 33 of Set 1 | kangaatsiaq
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | progreso
# Processing Record 36 of Set 1 | laukaa
# Processing Record 37 of Set 1 | saskylakh
# Processing Record 38 of Set 1 | tuktoyaktuk
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | qasigiannguit
# Processing Record 41 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | bubaque
# Processing Record 47 of Set 1 | mahebourg
# Processing Record 48 of Set 1 | clyde river
# Processing Record 49 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | xichang
# Processing Record 2 of Set 2 | kapaa
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | egvekinot
# Processing Record 5 of Set 2 | thompson
# Processing Record 6 of Set 2 | keti bandar
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | shelburne
# Processing Record 9 of Set 2 | kavaratti
# Processing Record 10 of Set 2 | poum
# Processing Record 11 of Set 2 | sibolga
# Processing Record 12 of Set 2 | albany
# Processing Record 13 of Set 2 | provideniya
# Processing Record 14 of Set 2 | half moon bay
# Processing Record 15 of Set 2 | vaini
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | ribeira grande
# Processing Record 18 of Set 2 | atuona
# Processing Record 19 of Set 2 | airai
# Processing Record 20 of Set 2 | kasungu
# Processing Record 21 of Set 2 | puri
# Processing Record 22 of Set 2 | great yarmouth
# Processing Record 23 of Set 2 | namatanai
# Processing Record 24 of Set 2 | sechura
# Processing Record 25 of Set 2 | cape town
# Processing Record 26 of Set 2 | wanning
# Processing Record 27 of Set 2 | haines junction
# Processing Record 28 of Set 2 | roma
# Processing Record 29 of Set 2 | arlit
# Processing Record 30 of Set 2 | chuy
# Processing Record 31 of Set 2 | kemijarvi
# Processing Record 32 of Set 2 | kirkland lake
# Processing Record 33 of Set 2 | birjand
# Processing Record 34 of Set 2 | cartagena
# Processing Record 35 of Set 2 | hamilton
# Processing Record 36 of Set 2 | baraboo
# Processing Record 37 of Set 2 | aksu
# Processing Record 38 of Set 2 | eureka
# Processing Record 39 of Set 2 | rio gallegos
# Processing Record 40 of Set 2 | sitka
# Processing Record 41 of Set 2 | matamoros
# Processing Record 42 of Set 2 | volchansk
# Processing Record 43 of Set 2 | banmo
# City not found. Skipping...
# Processing Record 44 of Set 2 | arraial do cabo
# Processing Record 45 of Set 2 | wuxue
# Processing Record 46 of Set 2 | valverde del camino
# Processing Record 47 of Set 2 | saint george
# Processing Record 48 of Set 2 | pevek
# Processing Record 49 of Set 2 | fare
# Processing Record 50 of Set 2 | lompoc
# Processing Record 1 of Set 3 | kodiak
# Processing Record 2 of Set 3 | beloha
# Processing Record 3 of Set 3 | marzuq
# Processing Record 4 of Set 3 | lorengau
# Processing Record 5 of Set 3 | qrendi
# Processing Record 6 of Set 3 | barra da estiva
# Processing Record 7 of Set 3 | cherskiy
# Processing Record 8 of Set 3 | richards bay
# Processing Record 9 of Set 3 | copiapo
# Processing Record 10 of Set 3 | motomiya
# Processing Record 11 of Set 3 | roanoke rapids
# Processing Record 12 of Set 3 | cabo san lucas
# Processing Record 13 of Set 3 | hun
# Processing Record 14 of Set 3 | butaritari
# Processing Record 15 of Set 3 | port blair
# Processing Record 16 of Set 3 | husavik
# Processing Record 17 of Set 3 | souillac
# Processing Record 18 of Set 3 | saint-philippe
# Processing Record 19 of Set 3 | izhmorskiy
# Processing Record 20 of Set 3 | pacific grove
# Processing Record 21 of Set 3 | mehamn
# Processing Record 22 of Set 3 | kaitangata
# Processing Record 23 of Set 3 | mayskiy
# Processing Record 24 of Set 3 | dudinka
# Processing Record 25 of Set 3 | santiago del estero
# Processing Record 26 of Set 3 | ihosy
# Processing Record 27 of Set 3 | dingle
# Processing Record 28 of Set 3 | sinnamary
# Processing Record 29 of Set 3 | ahipara
# Processing Record 30 of Set 3 | birao
# Processing Record 31 of Set 3 | mandla
# Processing Record 32 of Set 3 | saint-pierre
# Processing Record 33 of Set 3 | viedma
# Processing Record 34 of Set 3 | matara
# Processing Record 35 of Set 3 | skalat
# Processing Record 36 of Set 3 | faanui
# Processing Record 37 of Set 3 | harper
# Processing Record 38 of Set 3 | grand gaube
# Processing Record 39 of Set 3 | portland
# Processing Record 40 of Set 3 | lata
# Processing Record 41 of Set 3 | hobart
# Processing Record 42 of Set 3 | hithadhoo
# Processing Record 43 of Set 3 | goundam
# Processing Record 44 of Set 3 | chokurdakh
# Processing Record 45 of Set 3 | huilong
# Processing Record 46 of Set 3 | tasiilaq
# Processing Record 47 of Set 3 | salalah
# Processing Record 48 of Set 3 | nikolskoye
# Processing Record 49 of Set 3 | san ramon
# Processing Record 50 of Set 3 | longyearbyen
# Processing Record 1 of Set 4 | ostrovnoy
# Processing Record 2 of Set 4 | aykhal
# Processing Record 3 of Set 4 | dali
# Processing Record 4 of Set 4 | fomboni
# Processing Record 5 of Set 4 | sabzevar
# Processing Record 6 of Set 4 | zhigansk
# Processing Record 7 of Set 4 | maragogi
# Processing Record 8 of Set 4 | beringovskiy
# Processing Record 9 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 4 | fairbanks
# Processing Record 11 of Set 4 | ornskoldsvik
# Processing Record 12 of Set 4 | vaasa
# Processing Record 13 of Set 4 | kahului
# Processing Record 14 of Set 4 | prince rupert
# Processing Record 15 of Set 4 | kedrovyy
# Processing Record 16 of Set 4 | talgar
# Processing Record 17 of Set 4 | pangnirtung
# Processing Record 18 of Set 4 | cidreira
# Processing Record 19 of Set 4 | codrington
# Processing Record 20 of Set 4 | najran
# Processing Record 21 of Set 4 | bethel
# Processing Record 22 of Set 4 | naze
# Processing Record 23 of Set 4 | talnakh
# Processing Record 24 of Set 4 | hirara
# Processing Record 25 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 4 | iqaluit
# Processing Record 27 of Set 4 | tarbagatay
# Processing Record 28 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 4 | praia
# Processing Record 31 of Set 4 | micheweni
# Processing Record 32 of Set 4 | qaanaaq
# Processing Record 33 of Set 4 | buchanan
# Processing Record 34 of Set 4 | balkhash
# Processing Record 35 of Set 4 | iskateley
# Processing Record 36 of Set 4 | fallon
# Processing Record 37 of Set 4 | vanimo
# Processing Record 38 of Set 4 | severo-kurilsk
# Processing Record 39 of Set 4 | adrar
# Processing Record 40 of Set 4 | sao joao da barra
# Processing Record 41 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 4 | victoria
# Processing Record 43 of Set 4 | chiredzi
# Processing Record 44 of Set 4 | talisay
# Processing Record 45 of Set 4 | tyukhtet
# Processing Record 46 of Set 4 | dawlatabad
# Processing Record 47 of Set 4 | mugla
# Processing Record 48 of Set 4 | powell river
# Processing Record 49 of Set 4 | villa union
# Processing Record 50 of Set 4 | abu kamal
# Processing Record 1 of Set 5 | dukat
# Processing Record 2 of Set 5 | bambous virieux
# Processing Record 3 of Set 5 | ust-nera
# Processing Record 4 of Set 5 | dothan
# Processing Record 5 of Set 5 | hammerfest
# Processing Record 6 of Set 5 | chipinge
# Processing Record 7 of Set 5 | susurluk
# Processing Record 8 of Set 5 | torbat-e jam
# Processing Record 9 of Set 5 | burnie
# Processing Record 10 of Set 5 | saint-leu
# Processing Record 11 of Set 5 | berlevag
# Processing Record 12 of Set 5 | rassvet
# Processing Record 13 of Set 5 | akyab
# Processing Record 14 of Set 5 | buraydah
# Processing Record 15 of Set 5 | cacapava
# Processing Record 16 of Set 5 | karratha
# Processing Record 17 of Set 5 | nanortalik
# Processing Record 18 of Set 5 | marawi
# Processing Record 19 of Set 5 | kotovo
# Processing Record 20 of Set 5 | carnarvon
# Processing Record 21 of Set 5 | bathsheba
# Processing Record 22 of Set 5 | esperance
# Processing Record 23 of Set 5 | khatanga
# Processing Record 24 of Set 5 | sao filipe
# Processing Record 25 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 26 of Set 5 | nayoro
# Processing Record 27 of Set 5 | hasaki
# Processing Record 28 of Set 5 | paralimni
# Processing Record 29 of Set 5 | college
# Processing Record 30 of Set 5 | grand-santi
# Processing Record 31 of Set 5 | tiksi
# Processing Record 32 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 33 of Set 5 | stromness
# Processing Record 34 of Set 5 | lavrentiya
# Processing Record 35 of Set 5 | mikuni
# Processing Record 36 of Set 5 | east london
# Processing Record 37 of Set 5 | safipur
# Processing Record 38 of Set 5 | kati
# Processing Record 39 of Set 5 | upernavik
# Processing Record 40 of Set 5 | basco
# Processing Record 41 of Set 5 | inta
# Processing Record 42 of Set 5 | othonoi
# City not found. Skipping...
# Processing Record 43 of Set 5 | muros
# Processing Record 44 of Set 5 | seoul
# Processing Record 45 of Set 5 | antofagasta
# Processing Record 46 of Set 5 | turayf
# Processing Record 47 of Set 5 | pochutla
# Processing Record 48 of Set 5 | mujiayingzi
# Processing Record 49 of Set 5 | norman wells
# Processing Record 50 of Set 5 | glendive
# Processing Record 1 of Set 6 | tarakan
# Processing Record 2 of Set 6 | honiara
# Processing Record 3 of Set 6 | luba
# Processing Record 4 of Set 6 | ponta do sol
# Processing Record 5 of Set 6 | svetlogorsk
# Processing Record 6 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 7 of Set 6 | ibra
# Processing Record 8 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 6 | saint-georges
# Processing Record 11 of Set 6 | cobourg
# Processing Record 12 of Set 6 | faya
# Processing Record 13 of Set 6 | guerrero negro
# Processing Record 14 of Set 6 | segou
# Processing Record 15 of Set 6 | fort nelson
# Processing Record 16 of Set 6 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 17 of Set 6 | monte patria
# Processing Record 18 of Set 6 | axim
# Processing Record 19 of Set 6 | tombouctou
# Processing Record 20 of Set 6 | svetlaya
# Processing Record 21 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 6 | tilichiki
# Processing Record 23 of Set 6 | riyadh
# Processing Record 24 of Set 6 | klaksvik
# Processing Record 25 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 6 | changji
# Processing Record 27 of Set 6 | broome
# Processing Record 28 of Set 6 | cotonou
# Processing Record 29 of Set 6 | san juan
# Processing Record 30 of Set 6 | sinjah
# City not found. Skipping...
# Processing Record 31 of Set 6 | bartica
# Processing Record 32 of Set 6 | padang
# Processing Record 33 of Set 6 | qabis
# City not found. Skipping...
# Processing Record 34 of Set 6 | borovoy
# Processing Record 35 of Set 6 | orocue
# Processing Record 36 of Set 6 | laguna
# Processing Record 37 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 39 of Set 6 | pemangkat
# Processing Record 40 of Set 6 | saint anthony
# Processing Record 41 of Set 6 | chicama
# Processing Record 42 of Set 6 | kem
# Processing Record 43 of Set 6 | teguise
# Processing Record 44 of Set 6 | talaya
# Processing Record 45 of Set 6 | muli
# Processing Record 46 of Set 6 | nakhon phanom
# Processing Record 47 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 48 of Set 6 | itarema
# Processing Record 49 of Set 6 | karwar
# Processing Record 50 of Set 6 | tiznit
# Processing Record 1 of Set 7 | torbay
# Processing Record 2 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 3 of Set 7 | aklavik
# Processing Record 4 of Set 7 | tautira
# Processing Record 5 of Set 7 | carutapera
# Processing Record 6 of Set 7 | pozarevac
# Processing Record 7 of Set 7 | katsuura
# Processing Record 8 of Set 7 | lasa
# Processing Record 9 of Set 7 | westlock
# Processing Record 10 of Set 7 | coreau
# Processing Record 11 of Set 7 | vao
# Processing Record 12 of Set 7 | gornozavodsk
# Processing Record 13 of Set 7 | osakarovka
# Processing Record 14 of Set 7 | kihei
# Processing Record 15 of Set 7 | chingirlau
# Processing Record 16 of Set 7 | bonnyville
# Processing Record 17 of Set 7 | troy
# Processing Record 18 of Set 7 | santa cruz
# Processing Record 19 of Set 7 | santiago
# Processing Record 20 of Set 7 | san quintin
# Processing Record 21 of Set 7 | malanje
# Processing Record 22 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 7 | chilca
# Processing Record 24 of Set 7 | oktyabrskoye
# Processing Record 25 of Set 7 | suicheng
# Processing Record 26 of Set 7 | narsaq
# Processing Record 27 of Set 7 | khorramshahr
# Processing Record 28 of Set 7 | ronne
# Processing Record 29 of Set 7 | hofn
# Processing Record 30 of Set 7 | dubuque
# Processing Record 31 of Set 7 | chichli
# Processing Record 32 of Set 7 | marsh harbour
# Processing Record 33 of Set 7 | niquero
# Processing Record 34 of Set 7 | gao
# Processing Record 35 of Set 7 | port moresby
# Processing Record 36 of Set 7 | neiafu
# Processing Record 37 of Set 7 | koltubanovskiy
# Processing Record 38 of Set 7 | loandjili
# Processing Record 39 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 7 | tuatapere
# Processing Record 41 of Set 7 | goias
# Processing Record 42 of Set 7 | ucluelet
# Processing Record 43 of Set 7 | biak
# Processing Record 44 of Set 7 | susanville
# Processing Record 45 of Set 7 | mabaruma
# Processing Record 46 of Set 7 | nelson bay
# Processing Record 47 of Set 7 | caucel
# Processing Record 48 of Set 7 | kawalu
# Processing Record 49 of Set 7 | balakirevo
# Processing Record 50 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 8 | tenenkou
# Processing Record 2 of Set 8 | ballina
# Processing Record 3 of Set 8 | pokosnoye
# Processing Record 4 of Set 8 | fukuma
# Processing Record 5 of Set 8 | nalut
# Processing Record 6 of Set 8 | grand baie
# Processing Record 7 of Set 8 | vallenar
# Processing Record 8 of Set 8 | camacha
# Processing Record 9 of Set 8 | ustynivka
# Processing Record 10 of Set 8 | skofljica
# Processing Record 11 of Set 8 | kibala
# Processing Record 12 of Set 8 | kibungo
# Processing Record 13 of Set 8 | kapoeta
# Processing Record 14 of Set 8 | higuey
# City not found. Skipping...
# Processing Record 15 of Set 8 | gamba
# Processing Record 16 of Set 8 | det udom
# Processing Record 17 of Set 8 | sorland
# Processing Record 18 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 8 | palomares
# Processing Record 20 of Set 8 | male
# Processing Record 21 of Set 8 | kazerun
# Processing Record 22 of Set 8 | jinchengjiang
# City not found. Skipping...
# Processing Record 23 of Set 8 | muscat
# Processing Record 24 of Set 8 | abalak
# Processing Record 25 of Set 8 | igarka
# Processing Record 26 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 8 | vila franca do campo
# Processing Record 29 of Set 8 | calbuco
# Processing Record 30 of Set 8 | chalons-en-champagne
# Processing Record 31 of Set 8 | yar-sale
# Processing Record 32 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 8 | dalhousie
# Processing Record 34 of Set 8 | vanderhoof
# Processing Record 35 of Set 8 | nemuro
# Processing Record 36 of Set 8 | anadyr
# Processing Record 37 of Set 8 | dharchula
# Processing Record 38 of Set 8 | hambantota
# Processing Record 39 of Set 8 | port macquarie
# Processing Record 40 of Set 8 | victoria point
# Processing Record 41 of Set 8 | wana
# Processing Record 42 of Set 8 | bismarck
# Processing Record 43 of Set 8 | chakwal
# Processing Record 44 of Set 8 | chanute
# Processing Record 45 of Set 8 | yulara
# Processing Record 46 of Set 8 | bellevue
# Processing Record 47 of Set 8 | windsor
# Processing Record 48 of Set 8 | senanga
# Processing Record 49 of Set 8 | tomatlan
# Processing Record 50 of Set 8 | lagoa
# Processing Record 1 of Set 9 | ngunguru
# Processing Record 2 of Set 9 | natal
# Processing Record 3 of Set 9 | hualmay
# Processing Record 4 of Set 9 | iquitos
# Processing Record 5 of Set 9 | umm lajj
# Processing Record 6 of Set 9 | bilma
# Processing Record 7 of Set 9 | jabinyanah
# Processing Record 8 of Set 9 | tessalit
# Processing Record 9 of Set 9 | saldanha
# Processing Record 10 of Set 9 | gravdal
# Processing Record 11 of Set 9 | port hedland
# Processing Record 12 of Set 9 | the valley
# Processing Record 13 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 14 of Set 9 | severomuysk
# Processing Record 15 of Set 9 | severo-yeniseyskiy
# Processing Record 16 of Set 9 | aquiraz
# Processing Record 17 of Set 9 | bainbridge
# Processing Record 18 of Set 9 | sembakung
# Processing Record 19 of Set 9 | shubarshi
# Processing Record 20 of Set 9 | koslan
# Processing Record 21 of Set 9 | bulawayo
# Processing Record 22 of Set 9 | feltre
# Processing Record 23 of Set 9 | akhtanizovskaya
# Processing Record 24 of Set 9 | bandarbeyla
# Processing Record 25 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 9 | san pedro
# Processing Record 27 of Set 9 | taoudenni
# Processing Record 28 of Set 9 | tacuarembo
# Processing Record 29 of Set 9 | liniere
# City not found. Skipping...
# Processing Record 30 of Set 9 | melnikovo
# Processing Record 31 of Set 9 | sandomierz
# Processing Record 32 of Set 9 | havelock
# Processing Record 33 of Set 9 | necochea
# Processing Record 34 of Set 9 | ormara
# Processing Record 35 of Set 9 | yerbogachen
# Processing Record 36 of Set 9 | ambad
# Processing Record 37 of Set 9 | san vicente
# Processing Record 38 of Set 9 | senno
# Processing Record 39 of Set 9 | acapulco
# Processing Record 40 of Set 9 | camopi
# Processing Record 41 of Set 9 | dinsor
# City not found. Skipping...
# Processing Record 42 of Set 9 | solnechnyy
# Processing Record 43 of Set 9 | labrea
# Processing Record 44 of Set 9 | gewane
# Processing Record 45 of Set 9 | avera
# Processing Record 46 of Set 9 | jalu
# Processing Record 47 of Set 9 | yinchuan
# Processing Record 48 of Set 9 | taunggyi
# Processing Record 49 of Set 9 | banda aceh
# Processing Record 50 of Set 9 | kalabo
# Processing Record 1 of Set 10 | pisco
# Processing Record 2 of Set 10 | kautokeino
# Processing Record 3 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 4 of Set 10 | paamiut
# Processing Record 5 of Set 10 | dalbandin
# Processing Record 6 of Set 10 | mecca
# Processing Record 7 of Set 10 | camacupa
# Processing Record 8 of Set 10 | juba
# Processing Record 9 of Set 10 | ojinaga
# Processing Record 10 of Set 10 | general teran
# Processing Record 11 of Set 10 | kovdor
# Processing Record 12 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 13 of Set 10 | kieta
# Processing Record 14 of Set 10 | ventanas
# Processing Record 15 of Set 10 | manuk mangkaw
# Processing Record 16 of Set 10 | grindavik
# Processing Record 17 of Set 10 | bengkulu
# Processing Record 18 of Set 10 | nome
# Processing Record 19 of Set 10 | tadine
# Processing Record 20 of Set 10 | port lincoln
# Processing Record 21 of Set 10 | talcahuano
# Processing Record 22 of Set 10 | vestmanna
# Processing Record 23 of Set 10 | isangel
# Processing Record 24 of Set 10 | araouane
# Processing Record 25 of Set 10 | morbegno
# Processing Record 26 of Set 10 | geraldton
# Processing Record 27 of Set 10 | kalmunai
# Processing Record 28 of Set 10 | union hidalgo
# Processing Record 29 of Set 10 | takhtamygda
# Processing Record 30 of Set 10 | kavieng
# Processing Record 31 of Set 10 | hit
# Processing Record 32 of Set 10 | batagay
# Processing Record 33 of Set 10 | ravar
# Processing Record 34 of Set 10 | merauke
# Processing Record 35 of Set 10 | arshan
# Processing Record 36 of Set 10 | antalaha
# Processing Record 37 of Set 10 | dire
# Processing Record 38 of Set 10 | sabang
# Processing Record 39 of Set 10 | cheremukhovo
# Processing Record 40 of Set 10 | tambun
# Processing Record 41 of Set 10 | mmathubudukwane
# Processing Record 42 of Set 10 | dawei
# Processing Record 43 of Set 10 | altay
# Processing Record 44 of Set 10 | druzhba
# Processing Record 45 of Set 10 | norrtalje
# Processing Record 46 of Set 10 | hervey bay
# Processing Record 47 of Set 10 | magaria
# Processing Record 48 of Set 10 | tamale
# Processing Record 49 of Set 10 | olafsvik
# Processing Record 50 of Set 10 | keene
# Processing Record 1 of Set 11 | inhambane
# Processing Record 2 of Set 11 | lakes entrance
# Processing Record 3 of Set 11 | vikhorevka
# Processing Record 4 of Set 11 | valparaiso
# Processing Record 5 of Set 11 | cockburn town
# Processing Record 6 of Set 11 | ajdabiya
# Processing Record 7 of Set 11 | harlingen
# Processing Record 8 of Set 11 | westport
# Processing Record 9 of Set 11 | touros
# Processing Record 10 of Set 11 | atar
# Processing Record 11 of Set 11 | helensburgh
# Processing Record 12 of Set 11 | punta de bombon
# Processing Record 13 of Set 11 | pitimbu
# Processing Record 14 of Set 11 | dordrecht
# Processing Record 15 of Set 11 | manado
# Processing Record 16 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 11 | peleduy
# Processing Record 18 of Set 11 | acarau
# Processing Record 19 of Set 11 | coquimbo
# Processing Record 20 of Set 11 | sao francisco de paula
# Processing Record 21 of Set 11 | atherton
# Processing Record 22 of Set 11 | jatara
# Processing Record 23 of Set 11 | meulaboh
# Processing Record 24 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 25 of Set 11 | oussouye
# Processing Record 26 of Set 11 | priiskovyy
# Processing Record 27 of Set 11 | saint-francois
# Processing Record 28 of Set 11 | poindimie
# Processing Record 29 of Set 11 | chechat
# Processing Record 30 of Set 11 | mashhad
# Processing Record 31 of Set 11 | lazaro cardenas
# Processing Record 32 of Set 11 | siva
# Processing Record 33 of Set 11 | te anau
# Processing Record 34 of Set 11 | kiruna
# Processing Record 35 of Set 11 | ati
# Processing Record 36 of Set 11 | praia da vitoria
# Processing Record 37 of Set 11 | swabi
# Processing Record 38 of Set 11 | hilton head island
# Processing Record 39 of Set 11 | cacador
# Processing Record 40 of Set 11 | canavieiras
# Processing Record 41 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 42 of Set 11 | tchollire
# Processing Record 43 of Set 11 | lufilufi
# Processing Record 44 of Set 11 | evensk
# Processing Record 45 of Set 11 | soyo
# Processing Record 46 of Set 11 | burica
# City not found. Skipping...
# Processing Record 47 of Set 11 | malinao
# Processing Record 48 of Set 11 | quibdo
# Processing Record 49 of Set 11 | kutulik
# Processing Record 50 of Set 11 | lakhimpur
# Processing Record 1 of Set 12 | berbera
# Processing Record 2 of Set 12 | nha trang
# Processing Record 3 of Set 12 | yendi
# Processing Record 4 of Set 12 | campbell river
# Processing Record 5 of Set 12 | orange cove
# Processing Record 6 of Set 12 | tateyama
# Processing Record 7 of Set 12 | bellavista
# Processing Record 8 of Set 12 | pierre
# Processing Record 9 of Set 12 | ye
# City not found. Skipping...
# Processing Record 10 of Set 12 | ciudad bolivar
# Processing Record 11 of Set 12 | margate
# Processing Record 12 of Set 12 | aripuana
# Processing Record 13 of Set 12 | laizhou
# Processing Record 14 of Set 12 | mouzouras
# Processing Record 15 of Set 12 | tabuk
# Processing Record 16 of Set 12 | valdivia
# Processing Record 17 of Set 12 | iberia
# Processing Record 18 of Set 12 | mayachnyy
# Processing Record 19 of Set 12 | manzanillo
# Processing Record 20 of Set 12 | tajao
# Processing Record 21 of Set 12 | weinan
# Processing Record 22 of Set 12 | muravlenko
# Processing Record 23 of Set 12 | pangkalanbuun
# Processing Record 24 of Set 12 | skibbereen
# Processing Record 25 of Set 12 | auki
# Processing Record 26 of Set 12 | wilmington
# Processing Record 27 of Set 12 | thurso
# Processing Record 28 of Set 12 | ancud
# Processing Record 29 of Set 12 | verkhoyansk
# Processing Record 30 of Set 12 | brae
# Processing Record 31 of Set 12 | sydney
# Processing Record 32 of Set 12 | port hardy
# Processing Record 33 of Set 12 | point fortin
# Processing Record 34 of Set 12 | kayerkan
# Processing Record 35 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 36 of Set 12 | kabare
# Processing Record 37 of Set 12 | korla
# Processing Record 38 of Set 12 | nyaunglebin
# Processing Record 39 of Set 12 | sabla
# Processing Record 40 of Set 12 | nizhneangarsk
# Processing Record 41 of Set 12 | bambanglipuro
# Processing Record 42 of Set 12 | cottonwood
# Processing Record 43 of Set 12 | vestmannaeyjar
# Processing Record 44 of Set 12 | surat
# Processing Record 45 of Set 12 | lohardaga
# Processing Record 46 of Set 12 | quanzhou
# Processing Record 47 of Set 12 | kutum
# Processing Record 48 of Set 12 | elat
# Processing Record 49 of Set 12 | barrhead
# Processing Record 50 of Set 12 | novikovo
# Processing Record 1 of Set 13 | mundo nuevo
# Processing Record 2 of Set 13 | biloela
# Processing Record 3 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 4 of Set 13 | narasannapeta
# Processing Record 5 of Set 13 | sobolevo
# Processing Record 6 of Set 13 | palmer
# Processing Record 7 of Set 13 | bure
# Processing Record 8 of Set 13 | carlagan
# Processing Record 9 of Set 13 | cairns
# Processing Record 10 of Set 13 | baglung
# Processing Record 11 of Set 13 | juneau
# Processing Record 12 of Set 13 | goderich
# Processing Record 13 of Set 13 | mitchell
# Processing Record 14 of Set 13 | leningradskiy
# Processing Record 15 of Set 13 | alofi
# Processing Record 16 of Set 13 | baldovinesti
# Processing Record 17 of Set 13 | beruwala
# Processing Record 18 of Set 13 | pasighat
# Processing Record 19 of Set 13 | kamina
# Processing Record 20 of Set 13 | bud
# Processing Record 21 of Set 13 | khvorostyanka
# Processing Record 22 of Set 13 | raymond terrace
# Processing Record 23 of Set 13 | krasnoselkup
# Processing Record 24 of Set 13 | avesta
# Processing Record 25 of Set 13 | tau
# Processing Record 26 of Set 13 | thunder bay
# Processing Record 27 of Set 13 | shar
# Processing Record 28 of Set 13 | black river
# Processing Record 29 of Set 13 | bereda
# Processing Record 30 of Set 13 | carnot
# Processing Record 31 of Set 13 | sao felix do xingu
# Processing Record 32 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 33 of Set 13 | leninsk
# Processing Record 34 of Set 13 | sanchor
# Processing Record 35 of Set 13 | tsumeb
# Processing Record 36 of Set 13 | panama city
# Processing Record 37 of Set 13 | calabar
# Processing Record 38 of Set 13 | bronnoysund
# Processing Record 39 of Set 13 | calabozo
# Processing Record 40 of Set 13 | cururupu
# Processing Record 41 of Set 13 | amapa
# Processing Record 42 of Set 13 | wani
# Processing Record 43 of Set 13 | pontal do parana
# Processing Record 44 of Set 13 | biswan
# Processing Record 45 of Set 13 | segezha
# Processing Record 46 of Set 13 | doha
# Processing Record 47 of Set 13 | bilibino
# Processing Record 48 of Set 13 | lamu
# Processing Record 49 of Set 13 | kadipur
# Processing Record 50 of Set 13 | ndele
# Processing Record 1 of Set 14 | sovetskiy
# Processing Record 2 of Set 14 | nokaneng
# Processing Record 3 of Set 14 | maningrida
# Processing Record 4 of Set 14 | awjilah
# Processing Record 5 of Set 14 | rakitnoye
# Processing Record 6 of Set 14 | san policarpo
# Processing Record 7 of Set 14 | makakilo city
# Processing Record 8 of Set 14 | ninghai
# Processing Record 9 of Set 14 | anzio
# Processing Record 10 of Set 14 | mount gambier
# Processing Record 11 of Set 14 | saint-augustin
# Processing Record 12 of Set 14 | sangueya
# Processing Record 13 of Set 14 | gaoua
# Processing Record 14 of Set 14 | kannod
# Processing Record 15 of Set 14 | nanakuli
# Processing Record 16 of Set 14 | santa marta de tormes
# Processing Record 17 of Set 14 | valday
# Processing Record 18 of Set 14 | tefe
# Processing Record 19 of Set 14 | whitehorse
# Processing Record 20 of Set 14 | nipawin
# Processing Record 21 of Set 14 | kaele
# Processing Record 22 of Set 14 | englehart
# Processing Record 23 of Set 14 | tsienyane
# City not found. Skipping...
# Processing Record 24 of Set 14 | katangli
# Processing Record 25 of Set 14 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 26 of Set 14 | vardo
# Processing Record 27 of Set 14 | zaragoza
# Processing Record 28 of Set 14 | pizarro
# Processing Record 29 of Set 14 | livingston
# Processing Record 30 of Set 14 | ous
# Processing Record 31 of Set 14 | manyana
# Processing Record 32 of Set 14 | krasnyy sulin
# Processing Record 33 of Set 14 | tezu
# Processing Record 34 of Set 14 | ixtapa
# Processing Record 35 of Set 14 | samarai
# Processing Record 36 of Set 14 | rawson
# Processing Record 37 of Set 14 | empangeni
# Processing Record 38 of Set 14 | les cayes
# Processing Record 39 of Set 14 | garowe
# Processing Record 40 of Set 14 | morgan city
# Processing Record 41 of Set 14 | ust-barguzin
# Processing Record 42 of Set 14 | mercedes
# Processing Record 43 of Set 14 | mayumba
# Processing Record 44 of Set 14 | le port
# Processing Record 45 of Set 14 | puerto quijarro
# Processing Record 46 of Set 14 | uvalde
# Processing Record 47 of Set 14 | nara
# Processing Record 48 of Set 14 | dunedin
# Processing Record 49 of Set 14 | noumea
# Processing Record 50 of Set 14 | honningsvag
# Processing Record 1 of Set 15 | kolondieba
# Processing Record 2 of Set 15 | san jeronimo de tunan
# City not found. Skipping...
# Processing Record 3 of Set 15 | ushtobe
# Processing Record 4 of Set 15 | claremore
# Processing Record 5 of Set 15 | olavarria
# Processing Record 6 of Set 15 | qui nhon
# Processing Record 7 of Set 15 | gumdag
# Processing Record 8 of Set 15 | barranco
# Processing Record 9 of Set 15 | taksimo
# Processing Record 10 of Set 15 | sakakah
# Processing Record 11 of Set 15 | sabaudia
# Processing Record 12 of Set 15 | hami
# Processing Record 13 of Set 15 | son la
# Processing Record 14 of Set 15 | boddam
# Processing Record 15 of Set 15 | tommot
# Processing Record 16 of Set 15 | kokopo
# Processing Record 17 of Set 15 | sitio novo do tocantins
# Processing Record 18 of Set 15 | esna
# Processing Record 19 of Set 15 | sur
# Processing Record 20 of Set 15 | colac
# Processing Record 21 of Set 15 | belyy yar
# Processing Record 22 of Set 15 | sompeta
# Processing Record 23 of Set 15 | la macarena
# Processing Record 24 of Set 15 | havoysund
# Processing Record 25 of Set 15 | cheltenham
# Processing Record 26 of Set 15 | linhares
# Processing Record 27 of Set 15 | bontang
# Processing Record 28 of Set 15 | patea
# Processing Record 29 of Set 15 | tokur
# Processing Record 30 of Set 15 | uusikaupunki
# Processing Record 31 of Set 15 | fukue
# Processing Record 32 of Set 15 | matay
# Processing Record 33 of Set 15 | fershampenuaz
# Processing Record 34 of Set 15 | strezhevoy
# Processing Record 35 of Set 15 | oranjemund
# Processing Record 36 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 15 | garissa
# Processing Record 38 of Set 15 | sa kaeo
# Processing Record 39 of Set 15 | fort saint james
# Processing Record 40 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 41 of Set 15 | dong hoi
# Processing Record 42 of Set 15 | da lat
# Processing Record 43 of Set 15 | locri
# Processing Record 44 of Set 15 | luanda
# Processing Record 45 of Set 15 | marienburg
# Processing Record 46 of Set 15 | mandalgovi
# Processing Record 47 of Set 15 | hermiston
# Processing Record 48 of Set 15 | gat
# Processing Record 49 of Set 15 | asau
# Processing Record 50 of Set 15 | mizdah
# Processing Record 1 of Set 16 | sataua
# City not found. Skipping...
# Processing Record 2 of Set 16 | toma
# Processing Record 3 of Set 16 | chenzhou
# Processing Record 4 of Set 16 | mafinga
# Processing Record 5 of Set 16 | talawdi
# City not found. Skipping...
# Processing Record 6 of Set 16 | kattivakkam
# Processing Record 7 of Set 16 | nanaimo
# Processing Record 8 of Set 16 | karamea
# City not found. Skipping...
# Processing Record 9 of Set 16 | kongoussi
# Processing Record 10 of Set 16 | kyra
# Processing Record 11 of Set 16 | waddan
# Processing Record 12 of Set 16 | namibe
# Processing Record 13 of Set 16 | mackay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Georgetown   5.4112  100.3354     79.90        88          96
# 1          Ronchin  50.6000    3.1000     61.21        65          99
# 2    San Cristobal   7.7669  -72.2250     78.46        57          11
# 3      Port Alfred -33.5906   26.8910     58.15        55          83
# 4      New Norfolk -42.7826  147.0587     53.92        86          71
# ..             ...      ...       ...       ...       ...         ...
# 700      Kongoussi  13.3258   -1.5347     83.73        58          79
# 701           Kyra  49.5776  111.9753     48.70        96          84
# 702         Waddan  29.1614   16.1390     79.34        31           0
# 703         Namibe -15.1961   12.1522     62.06        88          50
# 704         Mackay -21.1500  149.2000     72.05        63          12
#
#      Wind Speed Country Current Description
# 0          4.70      MY     overcast clouds
# 1          5.03      FR     overcast clouds
# 2          5.50      VE          few clouds
# 3          3.40      ZA       broken clouds
# 4          1.01      AU       broken clouds
# ..          ...     ...                 ...
# 700        6.46      BF       broken clouds
# 701        3.94      RU       broken clouds
# 702       10.31      LY           clear sky
# 703        7.34      AO    scattered clouds
# 704       13.62      AU          few clouds
#
# [705 rows x 9 columns]

# %%
# Reorganizing the order of the columns
new_column_order = ["City", "Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Georgetown      MY   5.4112  100.3354     79.90        88          96
# 1          Ronchin      FR  50.6000    3.1000     61.21        65          99
# 2    San Cristobal      VE   7.7669  -72.2250     78.46        57          11
# 3      Port Alfred      ZA -33.5906   26.8910     58.15        55          83
# 4      New Norfolk      AU -42.7826  147.0587     53.92        86          71
# ..             ...     ...      ...       ...       ...       ...         ...
# 700      Kongoussi      BF  13.3258   -1.5347     83.73        58          79
# 701           Kyra      RU  49.5776  111.9753     48.70        96          84
# 702         Waddan      LY  29.1614   16.1390     79.34        31           0
# 703         Namibe      AO -15.1961   12.1522     62.06        88          50
# 704         Mackay      AU -21.1500  149.2000     72.05        63          12
#
#      Wind Speed Current Description
# 0          4.70     overcast clouds
# 1          5.03     overcast clouds
# 2          5.50          few clouds
# 3          3.40       broken clouds
# 4          1.01       broken clouds
# ..          ...                 ...
# 700        6.46       broken clouds
# 701        3.94       broken clouds
# 702       10.31           clear sky
# 703        7.34    scattered clouds
# 704       13.62          few clouds
#
# [705 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
import dataframe_image as dfi   # This is for save dataframe as png images
dfi.export(city_data_df.head(10), 'df_citydata.png')
