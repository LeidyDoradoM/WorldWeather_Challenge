# %% [markdown]
# ## Deliverable 1
# ### Generate a set of 2,000 random latitudes and longitudes and retrieve the nearest city using citipy module. Perform an API call with the OpenWeatherMap to retrieve the current weather description for each city and create a dataFrame containing the updated weather data.

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
from config import weather_api_key

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)  # to join lattitudes and longitudes as a tuple that have the same index
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_url = url + "&q=" + city.replace(" ","+")
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=040b14fdfa7604c2afbd31fce0eb809e&q=kununurra

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in our list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yantal
# Processing Record 2 of Set 1 | kamaishi
# Processing Record 3 of Set 1 | hualmay
# Processing Record 4 of Set 1 | chuy
# Processing Record 5 of Set 1 | tyulgan
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | provideniya
# Processing Record 8 of Set 1 | tura
# Processing Record 9 of Set 1 | juneau
# Processing Record 10 of Set 1 | tazovskiy
# Processing Record 11 of Set 1 | mandalgovi
# Processing Record 12 of Set 1 | itarema
# Processing Record 13 of Set 1 | camopi
# Processing Record 14 of Set 1 | portland
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | hasaki
# Processing Record 17 of Set 1 | businga
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | ust-ilimsk
# Processing Record 20 of Set 1 | isangel
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | castro
# Processing Record 23 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 1 | kodiak
# Processing Record 25 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 1 | nuristan
# Processing Record 27 of Set 1 | yulara
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | bethel
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | gympie
# Processing Record 32 of Set 1 | boende
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | honiara
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | punta arenas
# Processing Record 40 of Set 1 | lavrentiya
# Processing Record 41 of Set 1 | mayo
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | leningradskiy
# Processing Record 44 of Set 1 | veraval
# Processing Record 45 of Set 1 | lompoc
# Processing Record 46 of Set 1 | esperance
# Processing Record 47 of Set 1 | katsuura
# Processing Record 48 of Set 1 | hithadhoo
# Processing Record 49 of Set 1 | kindu
# Processing Record 50 of Set 1 | chokurdakh
# Processing Record 1 of Set 2 | khatanga
# Processing Record 2 of Set 2 | carnarvon
# Processing Record 3 of Set 2 | karwar
# Processing Record 4 of Set 2 | gerzat
# Processing Record 5 of Set 2 | taoudenni
# Processing Record 6 of Set 2 | nikolskoye
# Processing Record 7 of Set 2 | ribeira grande
# Processing Record 8 of Set 2 | torbay
# Processing Record 9 of Set 2 | ponta delgada
# Processing Record 10 of Set 2 | rockhampton
# Processing Record 11 of Set 2 | gambela
# Processing Record 12 of Set 2 | tubruq
# City not found. Skipping...
# Processing Record 13 of Set 2 | saskylakh
# Processing Record 14 of Set 2 | avarua
# Processing Record 15 of Set 2 | tasiilaq
# Processing Record 16 of Set 2 | barrow
# Processing Record 17 of Set 2 | georgetown
# Processing Record 18 of Set 2 | altay
# Processing Record 19 of Set 2 | victoria
# Processing Record 20 of Set 2 | san benito abad
# Processing Record 21 of Set 2 | shepsi
# Processing Record 22 of Set 2 | rodrigues alves
# Processing Record 23 of Set 2 | north bend
# Processing Record 24 of Set 2 | new norfolk
# Processing Record 25 of Set 2 | lata
# Processing Record 26 of Set 2 | port macquarie
# Processing Record 27 of Set 2 | barga
# Processing Record 28 of Set 2 | bredasdorp
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | greensboro
# Processing Record 31 of Set 2 | ayr
# Processing Record 32 of Set 2 | rocha
# Processing Record 33 of Set 2 | celendin
# Processing Record 34 of Set 2 | mar del plata
# Processing Record 35 of Set 2 | lebu
# Processing Record 36 of Set 2 | liaozhong
# Processing Record 37 of Set 2 | axim
# Processing Record 38 of Set 2 | bacungan
# Processing Record 39 of Set 2 | oranjestad
# Processing Record 40 of Set 2 | atuona
# Processing Record 41 of Set 2 | saryshagan
# City not found. Skipping...
# Processing Record 42 of Set 2 | renningen
# Processing Record 43 of Set 2 | kloulklubed
# Processing Record 44 of Set 2 | rawson
# Processing Record 45 of Set 2 | san jose
# Processing Record 46 of Set 2 | rapid valley
# Processing Record 47 of Set 2 | hangu
# Processing Record 48 of Set 2 | zonguldak
# Processing Record 49 of Set 2 | misratah
# Processing Record 50 of Set 2 | qaanaaq
# Processing Record 1 of Set 3 | manavalakurichi
# Processing Record 2 of Set 3 | maykain
# City not found. Skipping...
# Processing Record 3 of Set 3 | meulaboh
# Processing Record 4 of Set 3 | chapais
# Processing Record 5 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 3 | saint-georges
# Processing Record 7 of Set 3 | santa maria
# Processing Record 8 of Set 3 | bambous virieux
# Processing Record 9 of Set 3 | sao joao da barra
# Processing Record 10 of Set 3 | arkhonskaya
# Processing Record 11 of Set 3 | butaritari
# Processing Record 12 of Set 3 | arlit
# Processing Record 13 of Set 3 | aklavik
# Processing Record 14 of Set 3 | saint-philippe
# Processing Record 15 of Set 3 | dunedin
# Processing Record 16 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 3 | muli
# Processing Record 18 of Set 3 | vanimo
# Processing Record 19 of Set 3 | dikson
# Processing Record 20 of Set 3 | chicama
# Processing Record 21 of Set 3 | half moon bay
# Processing Record 22 of Set 3 | souillac
# Processing Record 23 of Set 3 | thompson
# Processing Record 24 of Set 3 | bengkulu
# Processing Record 25 of Set 3 | ponta do sol
# Processing Record 26 of Set 3 | mayor pablo lagerenza
# Processing Record 27 of Set 3 | suntar
# Processing Record 28 of Set 3 | tuktoyaktuk
# Processing Record 29 of Set 3 | zhanakorgan
# Processing Record 30 of Set 3 | ostrovnoy
# Processing Record 31 of Set 3 | manzhouli
# Processing Record 32 of Set 3 | kruisfontein
# Processing Record 33 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 3 | kavieng
# Processing Record 35 of Set 3 | kenai
# Processing Record 36 of Set 3 | necochea
# Processing Record 37 of Set 3 | kaitangata
# Processing Record 38 of Set 3 | sadu
# Processing Record 39 of Set 3 | arraial do cabo
# Processing Record 40 of Set 3 | severo-kurilsk
# Processing Record 41 of Set 3 | kushiro
# Processing Record 42 of Set 3 | vestmannaeyjar
# Processing Record 43 of Set 3 | tommot
# Processing Record 44 of Set 3 | zhangye
# Processing Record 45 of Set 3 | sohag
# Processing Record 46 of Set 3 | busselton
# Processing Record 47 of Set 3 | port elizabeth
# Processing Record 48 of Set 3 | ola
# Processing Record 49 of Set 3 | boguszow-gorce
# Processing Record 50 of Set 3 | mufumbwe
# Processing Record 1 of Set 4 | sao filipe
# Processing Record 2 of Set 4 | mopipi
# Processing Record 3 of Set 4 | rimbey
# Processing Record 4 of Set 4 | cherskiy
# Processing Record 5 of Set 4 | nuuk
# Processing Record 6 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 4 | xiaoweizhai
# Processing Record 8 of Set 4 | baiao
# Processing Record 9 of Set 4 | inhambane
# Processing Record 10 of Set 4 | florence
# Processing Record 11 of Set 4 | flinders
# Processing Record 12 of Set 4 | kayerkan
# Processing Record 13 of Set 4 | ampanihy
# Processing Record 14 of Set 4 | saldanha
# Processing Record 15 of Set 4 | thinadhoo
# Processing Record 16 of Set 4 | luang prabang
# Processing Record 17 of Set 4 | madera
# Processing Record 18 of Set 4 | tabulbah
# City not found. Skipping...
# Processing Record 19 of Set 4 | bossangoa
# Processing Record 20 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 4 | anchorage
# Processing Record 23 of Set 4 | goure
# Processing Record 24 of Set 4 | plouzane
# Processing Record 25 of Set 4 | loandjili
# Processing Record 26 of Set 4 | pinega
# Processing Record 27 of Set 4 | kirillov
# Processing Record 28 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 4 | tiznit
# Processing Record 30 of Set 4 | ushtobe
# Processing Record 31 of Set 4 | port alfred
# Processing Record 32 of Set 4 | hilo
# Processing Record 33 of Set 4 | south lake tahoe
# Processing Record 34 of Set 4 | kaduna
# Processing Record 35 of Set 4 | puerto ayora
# Processing Record 36 of Set 4 | tarakan
# Processing Record 37 of Set 4 | dinar
# Processing Record 38 of Set 4 | tonder
# Processing Record 39 of Set 4 | airai
# Processing Record 40 of Set 4 | georgiyevka
# Processing Record 41 of Set 4 | natitingou
# Processing Record 42 of Set 4 | ahipara
# Processing Record 43 of Set 4 | bowen
# Processing Record 44 of Set 4 | kidal
# Processing Record 45 of Set 4 | sitka
# Processing Record 46 of Set 4 | mezen
# Processing Record 47 of Set 4 | santa rosalia
# Processing Record 48 of Set 4 | canton
# Processing Record 49 of Set 4 | niamey
# Processing Record 50 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 1 of Set 5 | vanavara
# Processing Record 2 of Set 5 | tiksi
# Processing Record 3 of Set 5 | sept-iles
# Processing Record 4 of Set 5 | skjervoy
# Processing Record 5 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 5 | mitu
# Processing Record 7 of Set 5 | coquimbo
# Processing Record 8 of Set 5 | sinnar
# Processing Record 9 of Set 5 | padang
# Processing Record 10 of Set 5 | manokwari
# Processing Record 11 of Set 5 | qusar
# Processing Record 12 of Set 5 | kharp
# Processing Record 13 of Set 5 | karratha
# Processing Record 14 of Set 5 | east london
# Processing Record 15 of Set 5 | guerrero negro
# Processing Record 16 of Set 5 | russell
# Processing Record 17 of Set 5 | atar
# Processing Record 18 of Set 5 | qaqortoq
# Processing Record 19 of Set 5 | araouane
# Processing Record 20 of Set 5 | akyab
# Processing Record 21 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 5 | cockburn town
# Processing Record 23 of Set 5 | pisco
# Processing Record 24 of Set 5 | roald
# Processing Record 25 of Set 5 | rimouski
# Processing Record 26 of Set 5 | pilar
# Processing Record 27 of Set 5 | wanning
# Processing Record 28 of Set 5 | cap malheureux
# Processing Record 29 of Set 5 | buribay
# Processing Record 30 of Set 5 | northam
# Processing Record 31 of Set 5 | balkhash
# Processing Record 32 of Set 5 | dingle
# Processing Record 33 of Set 5 | vila
# Processing Record 34 of Set 5 | hobyo
# Processing Record 35 of Set 5 | upernavik
# Processing Record 36 of Set 5 | khuzhir
# Processing Record 37 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 38 of Set 5 | puertollano
# Processing Record 39 of Set 5 | sorland
# Processing Record 40 of Set 5 | atasu
# Processing Record 41 of Set 5 | watsa
# Processing Record 42 of Set 5 | bady bassitt
# Processing Record 43 of Set 5 | norman wells
# Processing Record 44 of Set 5 | touros
# Processing Record 45 of Set 5 | sungaipenuh
# Processing Record 46 of Set 5 | kamyshla
# Processing Record 47 of Set 5 | port lincoln
# Processing Record 48 of Set 5 | bradulet
# Processing Record 49 of Set 5 | pangoa
# Processing Record 50 of Set 5 | le mars
# Processing Record 1 of Set 6 | pangody
# Processing Record 2 of Set 6 | longyearbyen
# Processing Record 3 of Set 6 | bedford
# Processing Record 4 of Set 6 | san cristobal
# Processing Record 5 of Set 6 | big rapids
# Processing Record 6 of Set 6 | fare
# Processing Record 7 of Set 6 | aykhal
# Processing Record 8 of Set 6 | weymouth
# Processing Record 9 of Set 6 | nishihara
# Processing Record 10 of Set 6 | harindanga
# Processing Record 11 of Set 6 | pavlogradka
# Processing Record 12 of Set 6 | bamako
# Processing Record 13 of Set 6 | dolores
# Processing Record 14 of Set 6 | mahebourg
# Processing Record 15 of Set 6 | linhares
# Processing Record 16 of Set 6 | pangnirtung
# Processing Record 17 of Set 6 | xining
# Processing Record 18 of Set 6 | vuktyl
# Processing Record 19 of Set 6 | banyo
# Processing Record 20 of Set 6 | vardo
# Processing Record 21 of Set 6 | pacifica
# Processing Record 22 of Set 6 | tiruchchendur
# Processing Record 23 of Set 6 | santa catarina de tepehuanes
# Processing Record 24 of Set 6 | harper
# Processing Record 25 of Set 6 | mitsamiouli
# Processing Record 26 of Set 6 | qandala
# Processing Record 27 of Set 6 | noyabrsk
# Processing Record 28 of Set 6 | san patricio
# Processing Record 29 of Set 6 | laoag
# Processing Record 30 of Set 6 | neiafu
# Processing Record 31 of Set 6 | lalin
# Processing Record 32 of Set 6 | coihaique
# Processing Record 33 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 34 of Set 6 | sakakah
# Processing Record 35 of Set 6 | okhotsk
# Processing Record 36 of Set 6 | sungai siput utara
# City not found. Skipping...
# Processing Record 37 of Set 6 | autun
# Processing Record 38 of Set 6 | mecca
# Processing Record 39 of Set 6 | narsaq
# Processing Record 40 of Set 6 | arica
# Processing Record 41 of Set 6 | basirpur
# Processing Record 42 of Set 6 | mahanoro
# Processing Record 43 of Set 6 | winnemucca
# Processing Record 44 of Set 6 | nueva loja
# Processing Record 45 of Set 6 | shaunavon
# Processing Record 46 of Set 6 | geraldton
# Processing Record 47 of Set 6 | biskamzha
# Processing Record 48 of Set 6 | kemijarvi
# Processing Record 49 of Set 6 | hvolsvollur
# Processing Record 50 of Set 6 | pacific grove
# Processing Record 1 of Set 7 | japura
# Processing Record 2 of Set 7 | sinnamary
# Processing Record 3 of Set 7 | labuhan
# Processing Record 4 of Set 7 | butembo
# Processing Record 5 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 7 | nemuro
# Processing Record 7 of Set 7 | ginir
# Processing Record 8 of Set 7 | obo
# Processing Record 9 of Set 7 | lalibela
# Processing Record 10 of Set 7 | lagoa
# Processing Record 11 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 7 | garmsar
# Processing Record 13 of Set 7 | roebourne
# Processing Record 14 of Set 7 | husavik
# Processing Record 15 of Set 7 | mehamn
# Processing Record 16 of Set 7 | prieska
# Processing Record 17 of Set 7 | alice springs
# Processing Record 18 of Set 7 | avera
# Processing Record 19 of Set 7 | cidreira
# Processing Record 20 of Set 7 | sol-iletsk
# Processing Record 21 of Set 7 | palora
# Processing Record 22 of Set 7 | fureidis
# Processing Record 23 of Set 7 | quetigny
# Processing Record 24 of Set 7 | severobaykalsk
# Processing Record 25 of Set 7 | pevek
# Processing Record 26 of Set 7 | atherton
# Processing Record 27 of Set 7 | gawler
# Processing Record 28 of Set 7 | ruhengeri
# Processing Record 29 of Set 7 | indramayu
# Processing Record 30 of Set 7 | namibe
# Processing Record 31 of Set 7 | charters towers
# Processing Record 32 of Set 7 | dujuma
# City not found. Skipping...
# Processing Record 33 of Set 7 | mahbubabad
# Processing Record 34 of Set 7 | comodoro rivadavia
# Processing Record 35 of Set 7 | manuk mangkaw
# Processing Record 36 of Set 7 | alexandria
# Processing Record 37 of Set 7 | iqaluit
# Processing Record 38 of Set 7 | codrington
# Processing Record 39 of Set 7 | fukue
# Processing Record 40 of Set 7 | novyy urgal
# Processing Record 41 of Set 7 | gelemso
# Processing Record 42 of Set 7 | lagoa vermelha
# Processing Record 43 of Set 7 | pangai
# Processing Record 44 of Set 7 | borgosesia
# Processing Record 45 of Set 7 | maragogi
# Processing Record 46 of Set 7 | preeceville
# Processing Record 47 of Set 7 | calabozo
# Processing Record 48 of Set 7 | santa cruz
# Processing Record 49 of Set 7 | constitucion
# Processing Record 50 of Set 7 | kununurra
# Processing Record 1 of Set 8 | brigantine
# Processing Record 2 of Set 8 | egvekinot
# Processing Record 3 of Set 8 | nanortalik
# Processing Record 4 of Set 8 | aporawan
# City not found. Skipping...
# Processing Record 5 of Set 8 | natal
# Processing Record 6 of Set 8 | broken hill
# Processing Record 7 of Set 8 | ardmore
# Processing Record 8 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 8 | limbang
# Processing Record 10 of Set 8 | zhengjiatun
# Processing Record 11 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 8 | sapa
# Processing Record 13 of Set 8 | duartina
# Processing Record 14 of Set 8 | sanming
# Processing Record 15 of Set 8 | bilma
# Processing Record 16 of Set 8 | ipixuna
# Processing Record 17 of Set 8 | coahuayana
# Processing Record 18 of Set 8 | beyneu
# Processing Record 19 of Set 8 | vinnytsya
# Processing Record 20 of Set 8 | petauke
# Processing Record 21 of Set 8 | eurajoki
# Processing Record 22 of Set 8 | bend
# Processing Record 23 of Set 8 | udankudi
# Processing Record 24 of Set 8 | bubaque
# Processing Record 25 of Set 8 | stuttgart
# Processing Record 26 of Set 8 | ondangwa
# Processing Record 27 of Set 8 | san ignacio
# Processing Record 28 of Set 8 | baruun-urt
# Processing Record 29 of Set 8 | lorengau
# Processing Record 30 of Set 8 | kilindoni
# Processing Record 31 of Set 8 | hay river
# Processing Record 32 of Set 8 | tevriz
# Processing Record 33 of Set 8 | mogadishu
# Processing Record 34 of Set 8 | tombouctou
# Processing Record 35 of Set 8 | agar
# Processing Record 36 of Set 8 | peterhead
# Processing Record 37 of Set 8 | praia
# Processing Record 38 of Set 8 | svoge
# Processing Record 39 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 40 of Set 8 | beringovskiy
# Processing Record 41 of Set 8 | mana
# Processing Record 42 of Set 8 | andenes
# Processing Record 43 of Set 8 | hofn
# Processing Record 44 of Set 8 | pedernales
# Processing Record 45 of Set 8 | ilulissat
# Processing Record 46 of Set 8 | cabo san lucas
# Processing Record 47 of Set 8 | puerto suarez
# Processing Record 48 of Set 8 | naerbo
# Processing Record 49 of Set 8 | klaksvik
# Processing Record 50 of Set 8 | qiyang
# Processing Record 1 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 2 of Set 9 | langsa
# Processing Record 3 of Set 9 | manati
# Processing Record 4 of Set 9 | valentin gomez farias
# Processing Record 5 of Set 9 | fort frances
# Processing Record 6 of Set 9 | faanui
# Processing Record 7 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 8 of Set 9 | naftah
# City not found. Skipping...
# Processing Record 9 of Set 9 | turmalina
# Processing Record 10 of Set 9 | san quintin
# Processing Record 11 of Set 9 | bambari
# Processing Record 12 of Set 9 | griffith
# Processing Record 13 of Set 9 | saint-augustin
# Processing Record 14 of Set 9 | barcelos
# Processing Record 15 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 9 | aksu
# Processing Record 17 of Set 9 | oltu
# Processing Record 18 of Set 9 | grand gaube
# Processing Record 19 of Set 9 | caravelas
# Processing Record 20 of Set 9 | saint anthony
# Processing Record 21 of Set 9 | parsons
# Processing Record 22 of Set 9 | kutum
# Processing Record 23 of Set 9 | piacabucu
# Processing Record 24 of Set 9 | bathsheba
# Processing Record 25 of Set 9 | berbera
# Processing Record 26 of Set 9 | sturgeon bay
# Processing Record 27 of Set 9 | olafsvik
# Processing Record 28 of Set 9 | makakilo city
# Processing Record 29 of Set 9 | agirish
# Processing Record 30 of Set 9 | guanica
# Processing Record 31 of Set 9 | vostok
# Processing Record 32 of Set 9 | novyy rogachik
# Processing Record 33 of Set 9 | sidney
# Processing Record 34 of Set 9 | songjianghe
# Processing Record 35 of Set 9 | boundiali
# Processing Record 36 of Set 9 | vostochnyy
# Processing Record 37 of Set 9 | umm kaddadah
# Processing Record 38 of Set 9 | nhulunbuy
# Processing Record 39 of Set 9 | navolato
# Processing Record 40 of Set 9 | sciacca
# Processing Record 41 of Set 9 | abu kamal
# Processing Record 42 of Set 9 | shanhetun
# Processing Record 43 of Set 9 | mitake
# Processing Record 44 of Set 9 | nova olimpia
# Processing Record 45 of Set 9 | kano
# Processing Record 46 of Set 9 | darhan
# Processing Record 47 of Set 9 | aguimes
# Processing Record 48 of Set 9 | aktau
# Processing Record 49 of Set 9 | iralaya
# Processing Record 50 of Set 9 | alofi
# Processing Record 1 of Set 10 | katsiveli
# City not found. Skipping...
# Processing Record 2 of Set 10 | tshikapa
# Processing Record 3 of Set 10 | dubbo
# Processing Record 4 of Set 10 | tautira
# Processing Record 5 of Set 10 | phalodi
# Processing Record 6 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 7 of Set 10 | rio grande
# Processing Record 8 of Set 10 | mahibadhoo
# Processing Record 9 of Set 10 | yatou
# Processing Record 10 of Set 10 | bud
# Processing Record 11 of Set 10 | chengde
# Processing Record 12 of Set 10 | pianoro
# Processing Record 13 of Set 10 | cayenne
# Processing Record 14 of Set 10 | laurel
# Processing Record 15 of Set 10 | providence
# Processing Record 16 of Set 10 | deputatskiy
# Processing Record 17 of Set 10 | warkworth
# Processing Record 18 of Set 10 | kuryk
# Processing Record 19 of Set 10 | margate
# Processing Record 20 of Set 10 | alto araguaia
# Processing Record 21 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 22 of Set 10 | talnakh
# Processing Record 23 of Set 10 | komsomolskiy
# Processing Record 24 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 10 | chany
# Processing Record 26 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 10 | kingsport
# Processing Record 28 of Set 10 | chupa
# Processing Record 29 of Set 10 | outjo
# Processing Record 30 of Set 10 | kandi
# Processing Record 31 of Set 10 | paita
# Processing Record 32 of Set 10 | turka
# Processing Record 33 of Set 10 | ambilobe
# Processing Record 34 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 10 | wladyslawowo
# Processing Record 36 of Set 10 | yerbogachen
# Processing Record 37 of Set 10 | vila franca do campo
# Processing Record 38 of Set 10 | killybegs
# Processing Record 39 of Set 10 | redlands
# Processing Record 40 of Set 10 | cervo
# Processing Record 41 of Set 10 | la ronge
# Processing Record 42 of Set 10 | ravar
# Processing Record 43 of Set 10 | salisbury
# Processing Record 44 of Set 10 | otjimbingwe
# Processing Record 45 of Set 10 | yar-sale
# Processing Record 46 of Set 10 | virginia beach
# Processing Record 47 of Set 10 | makung
# City not found. Skipping...
# Processing Record 48 of Set 10 | cartagena
# Processing Record 49 of Set 10 | sale
# Processing Record 50 of Set 10 | ixtapa
# Processing Record 1 of Set 11 | varhaug
# Processing Record 2 of Set 11 | kalangala
# Processing Record 3 of Set 11 | toccoa
# Processing Record 4 of Set 11 | nabire
# Processing Record 5 of Set 11 | cap-aux-meules
# Processing Record 6 of Set 11 | valdez
# Processing Record 7 of Set 11 | chongwe
# Processing Record 8 of Set 11 | vao
# Processing Record 9 of Set 11 | copiapo
# Processing Record 10 of Set 11 | balkanabat
# Processing Record 11 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 11 | emba
# Processing Record 13 of Set 11 | marovoay
# Processing Record 14 of Set 11 | quelimane
# Processing Record 15 of Set 11 | bom jesus
# Processing Record 16 of Set 11 | san pedro
# Processing Record 17 of Set 11 | trinidad
# Processing Record 18 of Set 11 | salalah
# Processing Record 19 of Set 11 | lar
# Processing Record 20 of Set 11 | nadym
# Processing Record 21 of Set 11 | calantac
# Processing Record 22 of Set 11 | uyemskiy
# Processing Record 23 of Set 11 | leshukonskoye
# Processing Record 24 of Set 11 | ust-nera
# Processing Record 25 of Set 11 | eureka
# Processing Record 26 of Set 11 | mosetse
# Processing Record 27 of Set 11 | chunskiy
# Processing Record 28 of Set 11 | naryan-mar
# Processing Record 29 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 30 of Set 11 | shimoda
# Processing Record 31 of Set 11 | clyde river
# Processing Record 32 of Set 11 | coos bay
# Processing Record 33 of Set 11 | asten
# Processing Record 34 of Set 11 | lerik
# Processing Record 35 of Set 11 | poronaysk
# Processing Record 36 of Set 11 | te anau
# Processing Record 37 of Set 11 | namsos
# Processing Record 38 of Set 11 | carlagan
# Processing Record 39 of Set 11 | hervey bay
# Processing Record 40 of Set 11 | karpogory
# Processing Record 41 of Set 11 | wichita falls
# Processing Record 42 of Set 11 | hami
# Processing Record 43 of Set 11 | cam ranh
# Processing Record 44 of Set 11 | kristiinankaupunki
# Processing Record 45 of Set 11 | talcahuano
# Processing Record 46 of Set 11 | san ciro de acosta
# Processing Record 47 of Set 11 | salym
# Processing Record 48 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 11 | katherine
# Processing Record 50 of Set 11 | jatiroto
# Processing Record 1 of Set 12 | polovinnoye
# Processing Record 2 of Set 12 | shenjiamen
# Processing Record 3 of Set 12 | fort nelson
# Processing Record 4 of Set 12 | novoagansk
# Processing Record 5 of Set 12 | cabo rojo
# Processing Record 6 of Set 12 | korla
# Processing Record 7 of Set 12 | tiarei
# Processing Record 8 of Set 12 | teya
# Processing Record 9 of Set 12 | sorong
# Processing Record 10 of Set 12 | poso
# Processing Record 11 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 12 | ostersund
# Processing Record 13 of Set 12 | krasnoselkup
# Processing Record 14 of Set 12 | yeroham
# Processing Record 15 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 12 | kahului
# Processing Record 17 of Set 12 | khromtau
# Processing Record 18 of Set 12 | byron bay
# Processing Record 19 of Set 12 | atambua
# Processing Record 20 of Set 12 | vyyezdnoye
# Processing Record 21 of Set 12 | la roda
# Processing Record 22 of Set 12 | bonavista
# Processing Record 23 of Set 12 | vila velha
# Processing Record 24 of Set 12 | nelson bay
# Processing Record 25 of Set 12 | san ramon
# Processing Record 26 of Set 12 | saint-joseph
# Processing Record 27 of Set 12 | pedregal
# Processing Record 28 of Set 12 | ugoofaaru
# Processing Record 29 of Set 12 | hambantota
# Processing Record 30 of Set 12 | fortuna
# Processing Record 31 of Set 12 | geresk
# City not found. Skipping...
# Processing Record 32 of Set 12 | kholodnyy
# Processing Record 33 of Set 12 | goderich
# Processing Record 34 of Set 12 | tuatapere
# Processing Record 35 of Set 12 | kerman
# Processing Record 36 of Set 12 | santa rosa
# Processing Record 37 of Set 12 | alihe
# Processing Record 38 of Set 12 | saint-francois
# Processing Record 39 of Set 12 | mamallapuram
# Processing Record 40 of Set 12 | lancaster
# Processing Record 41 of Set 12 | eskasem
# City not found. Skipping...
# Processing Record 42 of Set 12 | mount gambier
# Processing Record 43 of Set 12 | chato
# Processing Record 44 of Set 12 | catalina foothills
# Processing Record 45 of Set 12 | peniche
# Processing Record 46 of Set 12 | quang ngai
# Processing Record 47 of Set 12 | nizwa
# Processing Record 48 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 49 of Set 12 | kasongo-lunda
# Processing Record 50 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 13 | fuyu
# Processing Record 2 of Set 13 | vaitape
# Processing Record 3 of Set 13 | washington
# Processing Record 4 of Set 13 | hirado
# Processing Record 5 of Set 13 | qasigiannguit
# Processing Record 6 of Set 13 | birjand
# Processing Record 7 of Set 13 | bletchley
# Processing Record 8 of Set 13 | la huerta
# Processing Record 9 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 10 of Set 13 | hudiksvall
# Processing Record 11 of Set 13 | matagami
# Processing Record 12 of Set 13 | blackwater
# Processing Record 13 of Set 13 | udachnyy
# Processing Record 14 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 15 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 16 of Set 13 | buraydah
# Processing Record 17 of Set 13 | kargil
# Processing Record 18 of Set 13 | doha
# Processing Record 19 of Set 13 | san vicente
# Processing Record 20 of Set 13 | bontang
# Processing Record 21 of Set 13 | vahan
# Processing Record 22 of Set 13 | weinan
# Processing Record 23 of Set 13 | shu
# Processing Record 24 of Set 13 | barcelona
# Processing Record 25 of Set 13 | broome
# Processing Record 26 of Set 13 | lazaro cardenas
# Processing Record 27 of Set 13 | komyshnya
# Processing Record 28 of Set 13 | paamiut
# Processing Record 29 of Set 13 | villa carlos paz
# Processing Record 30 of Set 13 | ust-kulom
# Processing Record 31 of Set 13 | pulandian
# Processing Record 32 of Set 13 | borogontsy
# Processing Record 33 of Set 13 | mizan teferi
# Processing Record 34 of Set 13 | faya
# Processing Record 35 of Set 13 | makurdi
# Processing Record 36 of Set 13 | artyshta
# Processing Record 37 of Set 13 | porto walter
# Processing Record 38 of Set 13 | kamenka
# Processing Record 39 of Set 13 | micheweni
# Processing Record 40 of Set 13 | talakan
# Processing Record 41 of Set 13 | grimari
# City not found. Skipping...
# Processing Record 42 of Set 13 | kasama
# Processing Record 43 of Set 13 | linguere
# Processing Record 44 of Set 13 | taseyevo
# Processing Record 45 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 13 | puerto carreno
# Processing Record 47 of Set 13 | port said
# Processing Record 48 of Set 13 | port hardy
# Processing Record 49 of Set 13 | tando jam
# Processing Record 50 of Set 13 | pierre
# Processing Record 1 of Set 14 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 14 | nuqui
# Processing Record 3 of Set 14 | vicksburg
# Processing Record 4 of Set 14 | lipin bor
# Processing Record 5 of Set 14 | grindavik
# Processing Record 6 of Set 14 | parabel
# Processing Record 7 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 14 | ketchikan
# Processing Record 9 of Set 14 | khash
# Processing Record 10 of Set 14 | burica
# City not found. Skipping...
# Processing Record 11 of Set 14 | shelopugino
# Processing Record 12 of Set 14 | salinopolis
# Processing Record 13 of Set 14 | uyuni
# Processing Record 14 of Set 14 | innisfail
# Processing Record 15 of Set 14 | laguna
# Processing Record 16 of Set 14 | poum
# Processing Record 17 of Set 14 | tetiyiv
# Processing Record 18 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 19 of Set 14 | strzelce opolskie
# Processing Record 20 of Set 14 | zeya
# Processing Record 21 of Set 14 | varkaus
# Processing Record 22 of Set 14 | monrovia
# Processing Record 23 of Set 14 | lovozero
# Processing Record 24 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 25 of Set 14 | kieta
# Processing Record 26 of Set 14 | gondanglegi
# Processing Record 27 of Set 14 | beloha
# Processing Record 28 of Set 14 | jujuy
# City not found. Skipping...
# Processing Record 29 of Set 14 | molteno
# Processing Record 30 of Set 14 | bati
# Processing Record 31 of Set 14 | port blair
# Processing Record 32 of Set 14 | villanueva
# Processing Record 33 of Set 14 | mombetsu
# Processing Record 34 of Set 14 | general pico
# Processing Record 35 of Set 14 | celestun
# Processing Record 36 of Set 14 | salamiyah
# Processing Record 37 of Set 14 | trincomalee
# Processing Record 38 of Set 14 | sayat
# Processing Record 39 of Set 14 | luderitz
# Processing Record 40 of Set 14 | puerto colombia
# Processing Record 41 of Set 14 | christchurch
# Processing Record 42 of Set 14 | wenling
# Processing Record 43 of Set 14 | sayaxche
# Processing Record 44 of Set 14 | whitehorse
# Processing Record 45 of Set 14 | westport
# Processing Record 46 of Set 14 | junin
# Processing Record 47 of Set 14 | bagdarin
# Processing Record 48 of Set 14 | acajutla
# Processing Record 49 of Set 14 | siyabuswa
# Processing Record 50 of Set 14 | port augusta
# Processing Record 1 of Set 15 | bandarbeyla
# Processing Record 2 of Set 15 | gunnedah
# Processing Record 3 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 4 of Set 15 | mayumba
# Processing Record 5 of Set 15 | ituni
# City not found. Skipping...
# Processing Record 6 of Set 15 | waitara
# Processing Record 7 of Set 15 | miami
# Processing Record 8 of Set 15 | chase
# Processing Record 9 of Set 15 | yumen
# Processing Record 10 of Set 15 | kupang
# Processing Record 11 of Set 15 | chumikan
# Processing Record 12 of Set 15 | matara
# Processing Record 13 of Set 15 | camocim
# Processing Record 14 of Set 15 | darlowo
# Processing Record 15 of Set 15 | pekan
# Processing Record 16 of Set 15 | palermo
# Processing Record 17 of Set 15 | kulhudhuffushi
# Processing Record 18 of Set 15 | nagornskiy
# Processing Record 19 of Set 15 | mananara
# Processing Record 20 of Set 15 | kazanskoye
# Processing Record 21 of Set 15 | alta floresta
# Processing Record 22 of Set 15 | kosonsoy
# Processing Record 23 of Set 15 | sur
# Processing Record 24 of Set 15 | warri
# Processing Record 25 of Set 15 | auki
# Processing Record 26 of Set 15 | mbini
# Processing Record 27 of Set 15 | kirakira
# Processing Record 28 of Set 15 | tessalit
# Processing Record 29 of Set 15 | harbour breton
# Processing Record 30 of Set 15 | shakhtinsk
# Processing Record 31 of Set 15 | kavaratti
# Processing Record 32 of Set 15 | canaries
# Processing Record 33 of Set 15 | takoradi
# Processing Record 34 of Set 15 | boyolangu
# Processing Record 35 of Set 15 | yaan
# Processing Record 36 of Set 15 | lungi
# Processing Record 37 of Set 15 | ucluelet
# Processing Record 38 of Set 15 | pokhara
# Processing Record 39 of Set 15 | bocanda
# Processing Record 40 of Set 15 | carauari
# Processing Record 41 of Set 15 | los llanos de aridane
# Processing Record 42 of Set 15 | merced
# Processing Record 43 of Set 15 | zachagansk
# City not found. Skipping...
# Processing Record 44 of Set 15 | bima
# Processing Record 45 of Set 15 | beeville
# Processing Record 46 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 47 of Set 15 | diamantino
# Processing Record 48 of Set 15 | nome
# Processing Record 49 of Set 15 | umm lajj
# Processing Record 50 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 1 of Set 16 | kiunga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Yantal  56.8471  105.2542     44.55        95         100
# 1      Kamaishi  39.2667  141.8833     68.05        89         100
# 2       Hualmay -11.0964  -77.6139     66.94        74          35
# 3          Chuy -33.6971  -53.4616     61.92        81          83
# 4       Tyulgan  52.3405   56.1660     51.19        93         100
# ..          ...      ...       ...       ...       ...         ...
# 683    Beeville  28.4008  -97.7483     96.35        49          40
# 684  Diamantino -14.4086  -56.4461     98.13        23          33
# 685        Nome  64.5011 -165.4064     49.10        93          90
# 686    Umm Lajj  25.0213   37.2685     87.60        61          84
# 687      Kiunga  -6.1219  141.2906     73.72       100         100
#
#      Wind Speed Country Current Description
# 0          1.90      RU          light rain
# 1          2.59      JP     overcast clouds
# 2          8.48      PE    scattered clouds
# 3         11.77      UY       broken clouds
# 4          6.02      RU     overcast clouds
# ..          ...     ...                 ...
# 683        9.22      US    scattered clouds
# 684        4.59      BR    scattered clouds
# 685       11.50      US                mist
# 686        8.08      SA       broken clouds
# 687        0.76      PG       moderate rain
#
# [688 rows x 9 columns]

# %%
# Reorganizing the order of the columns
new_column_order = ["City", "Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Yantal      RU  56.8471  105.2542     44.55        95         100
# 1      Kamaishi      JP  39.2667  141.8833     68.05        89         100
# 2       Hualmay      PE -11.0964  -77.6139     66.94        74          35
# 3          Chuy      UY -33.6971  -53.4616     61.92        81          83
# 4       Tyulgan      RU  52.3405   56.1660     51.19        93         100
# ..          ...     ...      ...       ...       ...       ...         ...
# 683    Beeville      US  28.4008  -97.7483     96.35        49          40
# 684  Diamantino      BR -14.4086  -56.4461     98.13        23          33
# 685        Nome      US  64.5011 -165.4064     49.10        93          90
# 686    Umm Lajj      SA  25.0213   37.2685     87.60        61          84
# 687      Kiunga      PG  -6.1219  141.2906     73.72       100         100
#
#      Wind Speed Current Description
# 0          1.90          light rain
# 1          2.59     overcast clouds
# 2          8.48    scattered clouds
# 3         11.77       broken clouds
# 4          6.02     overcast clouds
# ..          ...                 ...
# 683        9.22    scattered clouds
# 684        4.59    scattered clouds
# 685       11.50                mist
# 686        8.08       broken clouds
# 687        0.76       moderate rain
#
# [688 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
