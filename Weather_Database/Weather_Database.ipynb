# %% [markdown]
# ## Deliverable 1.  Retrieve the current weather description for each city and create a dataFrame containing the updated weather data.

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
from config import weather_api_key

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)  # to join lattitudes and longitudes as a tuple that have the same index
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_url = url + "&q=" + city.replace(" ","+")

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in our list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | usinsk
# Processing Record 3 of Set 1 | xam nua
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 1 | faanui
# Processing Record 7 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 1 | cidreira
# Processing Record 9 of Set 1 | lorengau
# Processing Record 10 of Set 1 | nador
# Processing Record 11 of Set 1 | te anau
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | victoria
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | rio gallegos
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | alice springs
# Processing Record 20 of Set 1 | vostok
# Processing Record 21 of Set 1 | tudela
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | panguna
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | fairview
# Processing Record 26 of Set 1 | bengkalis
# City not found. Skipping...
# Processing Record 27 of Set 1 | lanja
# Processing Record 28 of Set 1 | atuona
# Processing Record 29 of Set 1 | vestmanna
# Processing Record 30 of Set 1 | ust-nera
# Processing Record 31 of Set 1 | broken hill
# Processing Record 32 of Set 1 | hofn
# Processing Record 33 of Set 1 | jamestown
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | ribeira grande
# Processing Record 36 of Set 1 | chokurdakh
# Processing Record 37 of Set 1 | vinh
# Processing Record 38 of Set 1 | ponta do sol
# Processing Record 39 of Set 1 | roblin
# Processing Record 40 of Set 1 | darab
# Processing Record 41 of Set 1 | norman wells
# Processing Record 42 of Set 1 | provideniya
# Processing Record 43 of Set 1 | lebu
# Processing Record 44 of Set 1 | kahului
# Processing Record 45 of Set 1 | hilo
# Processing Record 46 of Set 1 | dikson
# Processing Record 47 of Set 1 | lagos
# Processing Record 48 of Set 1 | shieli
# Processing Record 49 of Set 1 | castro
# Processing Record 50 of Set 1 | shevchenkove
# Processing Record 1 of Set 2 | kawalu
# Processing Record 2 of Set 2 | saint-joseph
# Processing Record 3 of Set 2 | port alfred
# Processing Record 4 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 5 of Set 2 | arraial do cabo
# Processing Record 6 of Set 2 | talnakh
# Processing Record 7 of Set 2 | lompoc
# Processing Record 8 of Set 2 | kimbe
# Processing Record 9 of Set 2 | puerto ayora
# Processing Record 10 of Set 2 | bambous virieux
# Processing Record 11 of Set 2 | butaritari
# Processing Record 12 of Set 2 | albanel
# Processing Record 13 of Set 2 | qaanaaq
# Processing Record 14 of Set 2 | ruteng
# Processing Record 15 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 2 | mar del plata
# Processing Record 17 of Set 2 | saint-leu
# Processing Record 18 of Set 2 | acarau
# Processing Record 19 of Set 2 | mahebourg
# Processing Record 20 of Set 2 | east london
# Processing Record 21 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 22 of Set 2 | banepa
# Processing Record 23 of Set 2 | warri
# Processing Record 24 of Set 2 | qeshm
# Processing Record 25 of Set 2 | suamico
# Processing Record 26 of Set 2 | severo-kurilsk
# Processing Record 27 of Set 2 | cape town
# Processing Record 28 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | westport
# Processing Record 31 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 2 | khatanga
# Processing Record 33 of Set 2 | margate
# Processing Record 34 of Set 2 | port lincoln
# Processing Record 35 of Set 2 | katsuura
# Processing Record 36 of Set 2 | klaksvik
# Processing Record 37 of Set 2 | mali
# Processing Record 38 of Set 2 | gat
# Processing Record 39 of Set 2 | osa
# Processing Record 40 of Set 2 | georgetown
# Processing Record 41 of Set 2 | hithadhoo
# Processing Record 42 of Set 2 | airai
# Processing Record 43 of Set 2 | yirol
# City not found. Skipping...
# Processing Record 44 of Set 2 | arlit
# Processing Record 45 of Set 2 | paita
# Processing Record 46 of Set 2 | lata
# Processing Record 47 of Set 2 | kodiak
# Processing Record 48 of Set 2 | punta arenas
# Processing Record 49 of Set 2 | omsukchan
# Processing Record 50 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 3 | cabo san lucas
# Processing Record 3 of Set 3 | pevek
# Processing Record 4 of Set 3 | ilo
# Processing Record 5 of Set 3 | varzelandia
# Processing Record 6 of Set 3 | new norfolk
# Processing Record 7 of Set 3 | burica
# City not found. Skipping...
# Processing Record 8 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 3 | iskilip
# Processing Record 12 of Set 3 | seoul
# Processing Record 13 of Set 3 | bayangol
# Processing Record 14 of Set 3 | hovd
# Processing Record 15 of Set 3 | bluff
# Processing Record 16 of Set 3 | katima mulilo
# Processing Record 17 of Set 3 | saldanha
# Processing Record 18 of Set 3 | haines junction
# Processing Record 19 of Set 3 | dinsor
# City not found. Skipping...
# Processing Record 20 of Set 3 | gamba
# Processing Record 21 of Set 3 | mayumba
# Processing Record 22 of Set 3 | ixtapa
# Processing Record 23 of Set 3 | nikolskoye
# Processing Record 24 of Set 3 | mocoa
# Processing Record 25 of Set 3 | saskylakh
# Processing Record 26 of Set 3 | fomboni
# Processing Record 27 of Set 3 | srandakan
# Processing Record 28 of Set 3 | bengkulu
# Processing Record 29 of Set 3 | zelenogorskiy
# Processing Record 30 of Set 3 | kieta
# Processing Record 31 of Set 3 | darhan
# Processing Record 32 of Set 3 | oulainen
# Processing Record 33 of Set 3 | monze
# Processing Record 34 of Set 3 | batemans bay
# Processing Record 35 of Set 3 | esperance
# Processing Record 36 of Set 3 | malakal
# Processing Record 37 of Set 3 | beringovskiy
# Processing Record 38 of Set 3 | half moon bay
# Processing Record 39 of Set 3 | saint-philippe
# Processing Record 40 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 3 | burdur
# Processing Record 42 of Set 3 | terekli-mekteb
# Processing Record 43 of Set 3 | kerki
# City not found. Skipping...
# Processing Record 44 of Set 3 | merauke
# Processing Record 45 of Set 3 | kununurra
# Processing Record 46 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 47 of Set 3 | mahajanga
# Processing Record 48 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 3 | evensk
# Processing Record 50 of Set 3 | broome
# Processing Record 1 of Set 4 | oudtshoorn
# Processing Record 2 of Set 4 | thompson
# Processing Record 3 of Set 4 | barentu
# Processing Record 4 of Set 4 | mao
# Processing Record 5 of Set 4 | pamekasan
# Processing Record 6 of Set 4 | kiama
# Processing Record 7 of Set 4 | yellowknife
# Processing Record 8 of Set 4 | zhanatas
# City not found. Skipping...
# Processing Record 9 of Set 4 | torbay
# Processing Record 10 of Set 4 | tiksi
# Processing Record 11 of Set 4 | richards bay
# Processing Record 12 of Set 4 | cap malheureux
# Processing Record 13 of Set 4 | madang
# Processing Record 14 of Set 4 | christchurch
# Processing Record 15 of Set 4 | manggar
# Processing Record 16 of Set 4 | vega de alatorre
# Processing Record 17 of Set 4 | biak
# Processing Record 18 of Set 4 | mill valley
# Processing Record 19 of Set 4 | voh
# Processing Record 20 of Set 4 | port hueneme
# Processing Record 21 of Set 4 | tasiilaq
# Processing Record 22 of Set 4 | dakar
# Processing Record 23 of Set 4 | mecca
# Processing Record 24 of Set 4 | ruwi
# Processing Record 25 of Set 4 | ugra
# Processing Record 26 of Set 4 | lagoa
# Processing Record 27 of Set 4 | san patricio
# Processing Record 28 of Set 4 | dom pedrito
# Processing Record 29 of Set 4 | fortuna
# Processing Record 30 of Set 4 | sorland
# Processing Record 31 of Set 4 | maneadero
# Processing Record 32 of Set 4 | cleveland
# Processing Record 33 of Set 4 | edd
# Processing Record 34 of Set 4 | inarcs
# Processing Record 35 of Set 4 | kruisfontein
# Processing Record 36 of Set 4 | san carlos de bariloche
# Processing Record 37 of Set 4 | viedma
# Processing Record 38 of Set 4 | touros
# Processing Record 39 of Set 4 | olafsvik
# Processing Record 40 of Set 4 | noumea
# Processing Record 41 of Set 4 | martapura
# Processing Record 42 of Set 4 | hailar
# Processing Record 43 of Set 4 | caborca
# Processing Record 44 of Set 4 | saint george
# Processing Record 45 of Set 4 | amboise
# Processing Record 46 of Set 4 | geraldton
# Processing Record 47 of Set 4 | vila franca do campo
# Processing Record 48 of Set 4 | namatanai
# Processing Record 49 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 4 | kapaa
# Processing Record 1 of Set 5 | srednekolymsk
# Processing Record 2 of Set 5 | anadyr
# Processing Record 3 of Set 5 | port-gentil
# Processing Record 4 of Set 5 | harer
# Processing Record 5 of Set 5 | aykhal
# Processing Record 6 of Set 5 | pemangkat
# Processing Record 7 of Set 5 | muriwai beach
# Processing Record 8 of Set 5 | narsaq
# Processing Record 9 of Set 5 | mehamn
# Processing Record 10 of Set 5 | ahuimanu
# Processing Record 11 of Set 5 | bartica
# Processing Record 12 of Set 5 | rawlins
# Processing Record 13 of Set 5 | ilulissat
# Processing Record 14 of Set 5 | jodhpur
# Processing Record 15 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 5 | semnan
# Processing Record 17 of Set 5 | morondava
# Processing Record 18 of Set 5 | cayenne
# Processing Record 19 of Set 5 | ibipeba
# Processing Record 20 of Set 5 | aklavik
# Processing Record 21 of Set 5 | nome
# Processing Record 22 of Set 5 | ozinki
# Processing Record 23 of Set 5 | loreto
# Processing Record 24 of Set 5 | agirish
# Processing Record 25 of Set 5 | marystown
# Processing Record 26 of Set 5 | harnosand
# Processing Record 27 of Set 5 | beisfjord
# Processing Record 28 of Set 5 | coruripe
# Processing Record 29 of Set 5 | champerico
# Processing Record 30 of Set 5 | coquimbo
# Processing Record 31 of Set 5 | lang son
# Processing Record 32 of Set 5 | ossora
# Processing Record 33 of Set 5 | tual
# Processing Record 34 of Set 5 | praia
# Processing Record 35 of Set 5 | dawei
# Processing Record 36 of Set 5 | ugoofaaru
# Processing Record 37 of Set 5 | maghama
# City not found. Skipping...
# Processing Record 38 of Set 5 | sola
# Processing Record 39 of Set 5 | shuya
# Processing Record 40 of Set 5 | harper
# Processing Record 41 of Set 5 | salinas
# Processing Record 42 of Set 5 | babu
# Processing Record 43 of Set 5 | belaya gora
# Processing Record 44 of Set 5 | saint-pierre
# Processing Record 45 of Set 5 | bulalacao
# Processing Record 46 of Set 5 | florence
# Processing Record 47 of Set 5 | cherskiy
# Processing Record 48 of Set 5 | salalah
# Processing Record 49 of Set 5 | namibe
# Processing Record 50 of Set 5 | sudzha
# Processing Record 1 of Set 6 | barmer
# Processing Record 2 of Set 6 | acapulco
# Processing Record 3 of Set 6 | asau
# Processing Record 4 of Set 6 | san policarpo
# Processing Record 5 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 6 | winnemucca
# Processing Record 7 of Set 6 | altamira
# Processing Record 8 of Set 6 | ouro preto do oeste
# Processing Record 9 of Set 6 | aljezur
# Processing Record 10 of Set 6 | naze
# Processing Record 11 of Set 6 | naftah
# City not found. Skipping...
# Processing Record 12 of Set 6 | san quintin
# Processing Record 13 of Set 6 | kigoma
# Processing Record 14 of Set 6 | ambanja
# Processing Record 15 of Set 6 | boyolangu
# Processing Record 16 of Set 6 | port lavaca
# Processing Record 17 of Set 6 | yulara
# Processing Record 18 of Set 6 | vila velha
# Processing Record 19 of Set 6 | paralimni
# Processing Record 20 of Set 6 | halifax
# Processing Record 21 of Set 6 | itoman
# Processing Record 22 of Set 6 | mangrol
# Processing Record 23 of Set 6 | torata
# Processing Record 24 of Set 6 | wagar
# Processing Record 25 of Set 6 | lucapa
# Processing Record 26 of Set 6 | ispica
# Processing Record 27 of Set 6 | portland
# Processing Record 28 of Set 6 | gannan
# Processing Record 29 of Set 6 | port-de-paix
# City not found. Skipping...
# Processing Record 30 of Set 6 | tuktoyaktuk
# Processing Record 31 of Set 6 | maceio
# Processing Record 32 of Set 6 | holme
# Processing Record 33 of Set 6 | khandyga
# Processing Record 34 of Set 6 | chuy
# Processing Record 35 of Set 6 | kargasok
# Processing Record 36 of Set 6 | dunedin
# Processing Record 37 of Set 6 | flin flon
# Processing Record 38 of Set 6 | villarrica
# Processing Record 39 of Set 6 | rawson
# Processing Record 40 of Set 6 | walvis bay
# Processing Record 41 of Set 6 | carnarvon
# Processing Record 42 of Set 6 | sarkand
# Processing Record 43 of Set 6 | ancud
# Processing Record 44 of Set 6 | moron
# Processing Record 45 of Set 6 | shelburne
# Processing Record 46 of Set 6 | bosobolo
# Processing Record 47 of Set 6 | tynda
# Processing Record 48 of Set 6 | upernavik
# Processing Record 49 of Set 6 | najran
# Processing Record 50 of Set 6 | nizhniy tsasuchey
# Processing Record 1 of Set 7 | taoudenni
# Processing Record 2 of Set 7 | nyurba
# Processing Record 3 of Set 7 | hedaru
# Processing Record 4 of Set 7 | meulaboh
# Processing Record 5 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 7 | egvekinot
# Processing Record 7 of Set 7 | esfarayen
# Processing Record 8 of Set 7 | sao jose da coroa grande
# Processing Record 9 of Set 7 | yialos
# City not found. Skipping...
# Processing Record 10 of Set 7 | saint-augustin
# Processing Record 11 of Set 7 | padilla
# Processing Record 12 of Set 7 | sur
# Processing Record 13 of Set 7 | strazica
# City not found. Skipping...
# Processing Record 14 of Set 7 | siauliai
# Processing Record 15 of Set 7 | caravelas
# Processing Record 16 of Set 7 | grindavik
# Processing Record 17 of Set 7 | nanortalik
# Processing Record 18 of Set 7 | puerto del rosario
# Processing Record 19 of Set 7 | leningradskiy
# Processing Record 20 of Set 7 | montrose
# Processing Record 21 of Set 7 | kuusamo
# Processing Record 22 of Set 7 | bonavista
# Processing Record 23 of Set 7 | hasaki
# Processing Record 24 of Set 7 | north bend
# Processing Record 25 of Set 7 | bull savanna
# Processing Record 26 of Set 7 | susaki
# Processing Record 27 of Set 7 | maloh
# Processing Record 28 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 7 | tefe
# Processing Record 30 of Set 7 | mudgee
# Processing Record 31 of Set 7 | shaowu
# Processing Record 32 of Set 7 | camacha
# Processing Record 33 of Set 7 | umm kaddadah
# Processing Record 34 of Set 7 | luorong
# Processing Record 35 of Set 7 | baherden
# Processing Record 36 of Set 7 | pauini
# Processing Record 37 of Set 7 | karratha
# Processing Record 38 of Set 7 | two rivers
# Processing Record 39 of Set 7 | sao joao da barra
# Processing Record 40 of Set 7 | new albany
# Processing Record 41 of Set 7 | deputatskiy
# Processing Record 42 of Set 7 | oussouye
# Processing Record 43 of Set 7 | dharchula
# Processing Record 44 of Set 7 | komsomolskiy
# Processing Record 45 of Set 7 | senanga
# Processing Record 46 of Set 7 | lima
# Processing Record 47 of Set 7 | waseca
# Processing Record 48 of Set 7 | sinop
# Processing Record 49 of Set 7 | rabo de peixe
# Processing Record 50 of Set 7 | sitka
# Processing Record 1 of Set 8 | vikhorevka
# Processing Record 2 of Set 8 | adrar
# Processing Record 3 of Set 8 | ostrovnoy
# Processing Record 4 of Set 8 | tarakan
# Processing Record 5 of Set 8 | ketchikan
# Processing Record 6 of Set 8 | vestmannaeyjar
# Processing Record 7 of Set 8 | hobyo
# Processing Record 8 of Set 8 | henties bay
# Processing Record 9 of Set 8 | nacala
# Processing Record 10 of Set 8 | wattegama
# Processing Record 11 of Set 8 | korla
# Processing Record 12 of Set 8 | hailey
# Processing Record 13 of Set 8 | port hardy
# Processing Record 14 of Set 8 | providencia
# Processing Record 15 of Set 8 | raga
# Processing Record 16 of Set 8 | tuatapere
# Processing Record 17 of Set 8 | mishan
# Processing Record 18 of Set 8 | manicore
# Processing Record 19 of Set 8 | codrington
# Processing Record 20 of Set 8 | syamzha
# Processing Record 21 of Set 8 | diapaga
# Processing Record 22 of Set 8 | andenes
# Processing Record 23 of Set 8 | gunjur
# Processing Record 24 of Set 8 | shingu
# Processing Record 25 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 26 of Set 8 | vila
# Processing Record 27 of Set 8 | udachnyy
# Processing Record 28 of Set 8 | tromso
# Processing Record 29 of Set 8 | azimur
# City not found. Skipping...
# Processing Record 30 of Set 8 | san luis
# Processing Record 31 of Set 8 | tabuk
# Processing Record 32 of Set 8 | ponta delgada
# Processing Record 33 of Set 8 | clones
# Processing Record 34 of Set 8 | perustica
# City not found. Skipping...
# Processing Record 35 of Set 8 | eberndorf
# Processing Record 36 of Set 8 | mazatlan
# Processing Record 37 of Set 8 | muisne
# Processing Record 38 of Set 8 | ballitoville
# Processing Record 39 of Set 8 | sawtell
# Processing Record 40 of Set 8 | mozhaysk
# Processing Record 41 of Set 8 | porto velho
# Processing Record 42 of Set 8 | arkhangelsk
# Processing Record 43 of Set 8 | kindu
# Processing Record 44 of Set 8 | venice
# Processing Record 45 of Set 8 | laguna
# Processing Record 46 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 47 of Set 8 | tevaitoa
# Processing Record 48 of Set 8 | breytovo
# Processing Record 49 of Set 8 | moscow
# Processing Record 50 of Set 8 | kenai
# Processing Record 1 of Set 9 | carhuaz
# Processing Record 2 of Set 9 | ulsteinvik
# Processing Record 3 of Set 9 | conceicao do araguaia
# Processing Record 4 of Set 9 | hay river
# Processing Record 5 of Set 9 | hamilton
# Processing Record 6 of Set 9 | kharitonovo
# Processing Record 7 of Set 9 | tura
# Processing Record 8 of Set 9 | alofi
# Processing Record 9 of Set 9 | souillac
# Processing Record 10 of Set 9 | mnogovershinnyy
# Processing Record 11 of Set 9 | mosquera
# Processing Record 12 of Set 9 | chernyshevskiy
# Processing Record 13 of Set 9 | clyde river
# Processing Record 14 of Set 9 | nhulunbuy
# Processing Record 15 of Set 9 | ust-maya
# Processing Record 16 of Set 9 | diamantino
# Processing Record 17 of Set 9 | scarborough
# Processing Record 18 of Set 9 | sao filipe
# Processing Record 19 of Set 9 | kudahuvadhoo
# Processing Record 20 of Set 9 | tazovskiy
# Processing Record 21 of Set 9 | acapetahua
# Processing Record 22 of Set 9 | bambanglipuro
# Processing Record 23 of Set 9 | wawa
# Processing Record 24 of Set 9 | sagua la grande
# Processing Record 25 of Set 9 | uruguaiana
# Processing Record 26 of Set 9 | dicabisagan
# Processing Record 27 of Set 9 | ust-koksa
# Processing Record 28 of Set 9 | gwadar
# Processing Record 29 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 9 | sungaipenuh
# Processing Record 31 of Set 9 | fare
# Processing Record 32 of Set 9 | hambantota
# Processing Record 33 of Set 9 | jyvaskyla
# Processing Record 34 of Set 9 | kutum
# Processing Record 35 of Set 9 | tokur
# Processing Record 36 of Set 9 | riberalta
# Processing Record 37 of Set 9 | stara tura
# Processing Record 38 of Set 9 | enid
# Processing Record 39 of Set 9 | san borja
# Processing Record 40 of Set 9 | zaragoza
# Processing Record 41 of Set 9 | dukat
# Processing Record 42 of Set 9 | tamsweg
# Processing Record 43 of Set 9 | opunake
# Processing Record 44 of Set 9 | parczew
# Processing Record 45 of Set 9 | khasan
# Processing Record 46 of Set 9 | zarubino
# Processing Record 47 of Set 9 | tulun
# Processing Record 48 of Set 9 | kanye
# Processing Record 49 of Set 9 | tahoua
# Processing Record 50 of Set 9 | warrnambool
# Processing Record 1 of Set 10 | luderitz
# Processing Record 2 of Set 10 | rtishchevo
# Processing Record 3 of Set 10 | san cristobal
# Processing Record 4 of Set 10 | kenora
# Processing Record 5 of Set 10 | auki
# Processing Record 6 of Set 10 | gushikawa
# Processing Record 7 of Set 10 | buta
# Processing Record 8 of Set 10 | high prairie
# Processing Record 9 of Set 10 | fairbanks
# Processing Record 10 of Set 10 | isangel
# Processing Record 11 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 10 | ranong
# Processing Record 13 of Set 10 | weligama
# Processing Record 14 of Set 10 | constitucion
# Processing Record 15 of Set 10 | bend
# Processing Record 16 of Set 10 | atbasar
# Processing Record 17 of Set 10 | iqaluit
# Processing Record 18 of Set 10 | muroto
# Processing Record 19 of Set 10 | poum
# Processing Record 20 of Set 10 | zelenets
# Processing Record 21 of Set 10 | kidal
# Processing Record 22 of Set 10 | svetlogorsk
# Processing Record 23 of Set 10 | berbera
# Processing Record 24 of Set 10 | kavieng
# Processing Record 25 of Set 10 | port hedland
# Processing Record 26 of Set 10 | lasa
# Processing Record 27 of Set 10 | tocache
# Processing Record 28 of Set 10 | nara
# Processing Record 29 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 30 of Set 10 | qui nhon
# Processing Record 31 of Set 10 | kerrabe
# City not found. Skipping...
# Processing Record 32 of Set 10 | la ronge
# Processing Record 33 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 34 of Set 10 | zachagansk
# City not found. Skipping...
# Processing Record 35 of Set 10 | chapais
# Processing Record 36 of Set 10 | bundaberg
# Processing Record 37 of Set 10 | erenhot
# Processing Record 38 of Set 10 | karacakoy
# Processing Record 39 of Set 10 | verkhoshizhemye
# Processing Record 40 of Set 10 | alampur
# Processing Record 41 of Set 10 | eenhana
# Processing Record 42 of Set 10 | college
# Processing Record 43 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 44 of Set 10 | jacqueville
# Processing Record 45 of Set 10 | bachaquero
# Processing Record 46 of Set 10 | chadan
# Processing Record 47 of Set 10 | port victoria
# Processing Record 48 of Set 10 | cururupu
# Processing Record 49 of Set 10 | vagur
# Processing Record 50 of Set 10 | les cayes
# Processing Record 1 of Set 11 | tomaszow lubelski
# Processing Record 2 of Set 11 | tochimilco
# Processing Record 3 of Set 11 | jatai
# Processing Record 4 of Set 11 | da nang
# Processing Record 5 of Set 11 | rumuruti
# Processing Record 6 of Set 11 | lavrentiya
# Processing Record 7 of Set 11 | nuuk
# Processing Record 8 of Set 11 | brae
# Processing Record 9 of Set 11 | kangaatsiaq
# Processing Record 10 of Set 11 | vardo
# Processing Record 11 of Set 11 | ulladulla
# Processing Record 12 of Set 11 | the valley
# Processing Record 13 of Set 11 | bonnyville
# Processing Record 14 of Set 11 | lodja
# Processing Record 15 of Set 11 | vanimo
# Processing Record 16 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 17 of Set 11 | shalakusha
# Processing Record 18 of Set 11 | ouadda
# Processing Record 19 of Set 11 | bayburt
# Processing Record 20 of Set 11 | bethel
# Processing Record 21 of Set 11 | quelimane
# Processing Record 22 of Set 11 | at-bashi
# Processing Record 23 of Set 11 | charters towers
# Processing Record 24 of Set 11 | champawat
# Processing Record 25 of Set 11 | jiaojiang
# Processing Record 26 of Set 11 | kungurtug
# Processing Record 27 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 28 of Set 11 | todos santos
# Processing Record 29 of Set 11 | fukue
# Processing Record 30 of Set 11 | loandjili
# Processing Record 31 of Set 11 | fort saint james
# Processing Record 32 of Set 11 | dingle
# Processing Record 33 of Set 11 | marienburg
# Processing Record 34 of Set 11 | kaeo
# Processing Record 35 of Set 11 | sovetskiy
# Processing Record 36 of Set 11 | berettyoujfalu
# Processing Record 37 of Set 11 | mount gambier
# Processing Record 38 of Set 11 | slave lake
# Processing Record 39 of Set 11 | ko samui
# Processing Record 40 of Set 11 | fatezh
# Processing Record 41 of Set 11 | ola
# Processing Record 42 of Set 11 | lewistown
# Processing Record 43 of Set 11 | lewisporte
# Processing Record 44 of Set 11 | kargil
# Processing Record 45 of Set 11 | parry sound
# Processing Record 46 of Set 11 | tra vinh
# Processing Record 47 of Set 11 | yuzhnyy-kospashskiy
# Processing Record 48 of Set 11 | hami
# Processing Record 49 of Set 11 | praia da vitoria
# Processing Record 50 of Set 11 | sept-iles
# Processing Record 1 of Set 12 | belmonte
# Processing Record 2 of Set 12 | arman
# Processing Record 3 of Set 12 | yumen
# Processing Record 4 of Set 12 | beloha
# Processing Record 5 of Set 12 | horsham
# Processing Record 6 of Set 12 | ostrogozhsk
# Processing Record 7 of Set 12 | puerto leguizamo
# Processing Record 8 of Set 12 | zboriv
# Processing Record 9 of Set 12 | concepcion
# Processing Record 10 of Set 12 | port elizabeth
# Processing Record 11 of Set 12 | ardakan
# Processing Record 12 of Set 12 | aleksandrov gay
# Processing Record 13 of Set 12 | khani
# Processing Record 14 of Set 12 | north platte
# Processing Record 15 of Set 12 | micheweni
# Processing Record 16 of Set 12 | kuytun
# Processing Record 17 of Set 12 | kaitangata
# Processing Record 18 of Set 12 | inta
# Processing Record 19 of Set 12 | winslow
# Processing Record 20 of Set 12 | canandaigua
# Processing Record 21 of Set 12 | syedove
# Processing Record 22 of Set 12 | reconquista
# Processing Record 23 of Set 12 | bonthe
# Processing Record 24 of Set 12 | kerema
# Processing Record 25 of Set 12 | esil
# Processing Record 26 of Set 12 | nicoya
# Processing Record 27 of Set 12 | umm bab
# Processing Record 28 of Set 12 | chumikan
# Processing Record 29 of Set 12 | aitape
# Processing Record 30 of Set 12 | oranjemund
# Processing Record 31 of Set 12 | inhambane
# Processing Record 32 of Set 12 | srivardhan
# Processing Record 33 of Set 12 | worland
# Processing Record 34 of Set 12 | stepnyak
# Processing Record 35 of Set 12 | bandarbeyla
# Processing Record 36 of Set 12 | havoysund
# Processing Record 37 of Set 12 | tamandare
# Processing Record 38 of Set 12 | le vauclin
# Processing Record 39 of Set 12 | waddan
# Processing Record 40 of Set 12 | muravlenko
# Processing Record 41 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 12 | kloulklubed
# Processing Record 43 of Set 12 | polunochnoye
# Processing Record 44 of Set 12 | rexburg
# Processing Record 45 of Set 12 | high level
# Processing Record 46 of Set 12 | ketchenery
# City not found. Skipping...
# Processing Record 47 of Set 12 | menongue
# Processing Record 48 of Set 12 | emerald
# Processing Record 49 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 50 of Set 12 | pag
# Processing Record 1 of Set 13 | comodoro rivadavia
# Processing Record 2 of Set 13 | ishigaki
# Processing Record 3 of Set 13 | maues
# Processing Record 4 of Set 13 | bichena
# Processing Record 5 of Set 13 | luziania
# Processing Record 6 of Set 13 | arrecife
# Processing Record 7 of Set 13 | manokwari
# Processing Record 8 of Set 13 | vila do maio
# Processing Record 9 of Set 13 | rebrikha
# Processing Record 10 of Set 13 | kashi
# Processing Record 11 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 13 | acari
# Processing Record 13 of Set 13 | varna
# Processing Record 14 of Set 13 | prince george
# Processing Record 15 of Set 13 | saint anthony
# Processing Record 16 of Set 13 | gigmoto
# Processing Record 17 of Set 13 | lazaro cardenas
# Processing Record 18 of Set 13 | champua
# Processing Record 19 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 13 | impfondo
# Processing Record 21 of Set 13 | great bend
# Processing Record 22 of Set 13 | kulhudhuffushi
# Processing Record 23 of Set 13 | gazanjyk
# Processing Record 24 of Set 13 | campos sales
# Processing Record 25 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 27 of Set 13 | cotonou
# Processing Record 28 of Set 13 | miragoane
# Processing Record 29 of Set 13 | bilma
# Processing Record 30 of Set 13 | asfi
# Processing Record 31 of Set 13 | topeka
# Processing Record 32 of Set 13 | vesoul
# Processing Record 33 of Set 13 | muncie
# Processing Record 34 of Set 13 | avera
# Processing Record 35 of Set 13 | honiara
# Processing Record 36 of Set 13 | paamiut
# Processing Record 37 of Set 13 | greensburg
# Processing Record 38 of Set 13 | eureka
# Processing Record 39 of Set 13 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 40 of Set 13 | okhotsk
# Processing Record 41 of Set 13 | tumut
# Processing Record 42 of Set 13 | abnub
# Processing Record 43 of Set 13 | astana
# Processing Record 44 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 13 | nongan
# Processing Record 46 of Set 13 | nouadhibou
# Processing Record 47 of Set 13 | akdepe
# Processing Record 48 of Set 13 | inirida
# Processing Record 49 of Set 13 | la rioja
# Processing Record 50 of Set 13 | dongsheng
# Processing Record 1 of Set 14 | vadso
# Processing Record 2 of Set 14 | manisa
# Processing Record 3 of Set 14 | manzhouli
# Processing Record 4 of Set 14 | kodinsk
# Processing Record 5 of Set 14 | kaka
# Processing Record 6 of Set 14 | dudinka
# Processing Record 7 of Set 14 | flinders
# Processing Record 8 of Set 14 | artyom
# Processing Record 9 of Set 14 | faya
# Processing Record 10 of Set 14 | rampur
# Processing Record 11 of Set 14 | collierville
# Processing Record 12 of Set 14 | malazgirt
# Processing Record 13 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 14 of Set 14 | gweta
# Processing Record 15 of Set 14 | fez
# Processing Record 16 of Set 14 | grand gaube
# Processing Record 17 of Set 14 | bac lieu
# Processing Record 18 of Set 14 | longyearbyen
# Processing Record 19 of Set 14 | salvador
# Processing Record 20 of Set 14 | necochea
# Processing Record 21 of Set 14 | gurskoye
# City not found. Skipping...
# Processing Record 22 of Set 14 | mezen
# Processing Record 23 of Set 14 | yining
# Processing Record 24 of Set 14 | ponnani
# Processing Record 25 of Set 14 | hualmay
# Processing Record 26 of Set 14 | nargana
# Processing Record 27 of Set 14 | gobabis
# Processing Record 28 of Set 14 | tautira
# Processing Record 29 of Set 14 | guiberoua
# Processing Record 30 of Set 14 | saumur
# Processing Record 31 of Set 14 | wagga wagga
# Processing Record 32 of Set 14 | shimoda
# Processing Record 33 of Set 14 | road town
# Processing Record 34 of Set 14 | oriximina
# Processing Record 35 of Set 14 | ambovombe
# Processing Record 36 of Set 14 | teul
# City not found. Skipping...
# Processing Record 37 of Set 14 | luganville
# Processing Record 38 of Set 14 | humberto de campos
# Processing Record 39 of Set 14 | san benito
# Processing Record 40 of Set 14 | varena
# Processing Record 41 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 42 of Set 14 | araouane
# Processing Record 43 of Set 14 | mulege
# Processing Record 44 of Set 14 | roald
# Processing Record 45 of Set 14 | zhigansk
# Processing Record 46 of Set 14 | ahipara
# Processing Record 47 of Set 14 | nizhniy kuranakh
# Processing Record 48 of Set 14 | alenquer
# Processing Record 49 of Set 14 | mbaiki
# Processing Record 50 of Set 14 | pokhara
# Processing Record 1 of Set 15 | storforshei
# Processing Record 2 of Set 15 | haukipudas
# Processing Record 3 of Set 15 | kaduqli
# Processing Record 4 of Set 15 | biarritz
# Processing Record 5 of Set 15 | upata
# Processing Record 6 of Set 15 | japura
# Processing Record 7 of Set 15 | pingliang
# Processing Record 8 of Set 15 | thai binh
# Processing Record 9 of Set 15 | ayorou
# Processing Record 10 of Set 15 | shrewsbury
# Processing Record 11 of Set 15 | warburton
# Processing Record 12 of Set 15 | wenling
# Processing Record 13 of Set 15 | ankazoabo
# Processing Record 14 of Set 15 | san andres
# Processing Record 15 of Set 15 | lokosovo
# Processing Record 16 of Set 15 | borogontsy
# Processing Record 17 of Set 15 | kirakira
# Processing Record 18 of Set 15 | simao
# Processing Record 19 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 20 of Set 15 | koyelga
# Processing Record 21 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 15 | tema
# Processing Record 24 of Set 15 | santa cruz
# Processing Record 25 of Set 15 | santa catarina de tepehuanes
# Processing Record 26 of Set 15 | kuandian
# Processing Record 27 of Set 15 | saint-francois
# Processing Record 28 of Set 15 | karlstad
# Processing Record 29 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 30 of Set 15 | kalmunai
# Processing Record 31 of Set 15 | atasu
# Processing Record 32 of Set 15 | moba
# Processing Record 33 of Set 15 | turayf
# Processing Record 34 of Set 15 | taketa
# Processing Record 35 of Set 15 | kinkala
# Processing Record 36 of Set 15 | memmingen
# Processing Record 37 of Set 15 | turtkul
# City not found. Skipping...
# Processing Record 38 of Set 15 | north myrtle beach
# Processing Record 39 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 40 of Set 15 | fort nelson
# Processing Record 41 of Set 15 | sistranda
# Processing Record 42 of Set 15 | katobu
# Processing Record 43 of Set 15 | abhar
# Processing Record 44 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 15 | saint-georges
# Processing Record 46 of Set 15 | huarmey
# Processing Record 47 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 48 of Set 15 | khash
# Processing Record 49 of Set 15 | pisco
# Processing Record 50 of Set 15 | pavilosta
# Processing Record 1 of Set 16 | eyl
# Processing Record 2 of Set 16 | ust-tsilma
# Processing Record 3 of Set 16 | fevralsk
# City not found. Skipping...
# Processing Record 4 of Set 16 | ocos
# Processing Record 5 of Set 16 | moyale
# Processing Record 6 of Set 16 | atikokan
# Processing Record 7 of Set 16 | nueva loja
# Processing Record 8 of Set 16 | cap-aux-meules
# Processing Record 9 of Set 16 | teguise
# Processing Record 10 of Set 16 | makung
# City not found. Skipping...
# Processing Record 11 of Set 16 | zdvinsk
# Processing Record 12 of Set 16 | manbij
# Processing Record 13 of Set 16 | biloela
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Hobart -42.8794  147.3294     50.11        75          40
# 1            Usinsk  65.9939   57.5281     34.86        93          64
# 2           Xam Nua  20.4197  104.0439     64.65        86          99
# 3          Hermanus -34.4187   19.2345     54.90        82          43
# 4            Faanui -16.4833 -151.7500     76.84        64          69
# ..              ...      ...       ...       ...       ...         ...
# 691  Cap-Aux-Meules  47.3821  -61.8597     60.85       100          90
# 692         Teguise  29.0605  -13.5640     71.82        78          20
# 693         Zdvinsk  54.7021   78.6610     50.65        88          97
# 694          Manbij  36.5281   37.9549     72.37        76           0
# 695         Biloela -24.4167  150.5000     62.82        59           3
#
#      Wind Speed Country Current Description
# 0          3.00      AU          light rain
# 1         11.07      RU       broken clouds
# 2          1.43      LA     overcast clouds
# 3          3.53      ZA    scattered clouds
# 4         12.64      PF       broken clouds
# ..          ...     ...                 ...
# 691       14.97      CA       moderate rain
# 692       11.50      ES          few clouds
# 693       17.67      RU     overcast clouds
# 694       16.98      SY           clear sky
# 695        1.01      AU           clear sky
#
# [696 rows x 9 columns]

# %%
# Reorganizing the order of the columns
new_column_order = ["City", "Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Hobart      AU -42.8794  147.3294     50.11        75
# 1            Usinsk      RU  65.9939   57.5281     34.86        93
# 2           Xam Nua      LA  20.4197  104.0439     64.65        86
# 3          Hermanus      ZA -34.4187   19.2345     54.90        82
# 4            Faanui      PF -16.4833 -151.7500     76.84        64
# ..              ...     ...      ...       ...       ...       ...
# 691  Cap-Aux-Meules      CA  47.3821  -61.8597     60.85       100
# 692         Teguise      ES  29.0605  -13.5640     71.82        78
# 693         Zdvinsk      RU  54.7021   78.6610     50.65        88
# 694          Manbij      SY  36.5281   37.9549     72.37        76
# 695         Biloela      AU -24.4167  150.5000     62.82        59
#
#      Cloudiness  Wind Speed Current Description
# 0            40        3.00          light rain
# 1            64       11.07       broken clouds
# 2            99        1.43     overcast clouds
# 3            43        3.53    scattered clouds
# 4            69       12.64       broken clouds
# ..          ...         ...                 ...
# 691          90       14.97       moderate rain
# 692          20       11.50          few clouds
# 693          97       17.67     overcast clouds
# 694           0       16.98           clear sky
# 695           3        1.01           clear sky
#
# [696 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
